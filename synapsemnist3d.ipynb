# %%
# Cell 1: Test GPU
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

# Test tensor on GPU
x = torch.rand(5, 3).cuda()
print(f"\nTest tensor on GPU: {x.device}")
print("✓ GPU setup working!")
# Out:
# PyTorch version: 2.5.1
# CUDA available: True
# CUDA version: 12.1
# GPU: NVIDIA GeForce RTX 4060
# GPU Memory: 8.59 GB
#
# Test tensor on GPU: cuda:0
# ✓ GPU setup working!

# %%
# Navigate to your experiments folder
import os
os.chdir(r'C:\Users\User\Desktop\mnist\experiments\MedMNIST3D')
print(f"✓ Current directory: {os.getcwd()}")

# Verify GPU
import torch
print(f"✓ CUDA Available: {torch.cuda.is_available()}")
print(f"✓ GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NO GPU'}")
print(f"✓ GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
# Out:
# ✓ Current directory: C:\Users\User\Desktop\mnist\experiments\MedMNIST3D
# ✓ CUDA Available: True
# ✓ GPU: NVIDIA GeForce RTX 4060
# ✓ GPU Memory: 8.59 GB

# %%
# %cd C:/Users/User/Desktop/mnist/experiments/MedMNIST3D

# !python train_and_eval_pytorch.py \
    --data_flag synapsemnist3d \
    --output_root ./output/synapsemnist3d_run1 \
    --num_epochs 30 \
    --batch_size 16 \
    --download \
    --model_flag resnet50 \
    --run run1
# Out:
# C:\Users\User\Desktop\mnist\experiments\MedMNIST3D
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# ==> Building and training model...
# cur_best_auc: 0.6792635658914727
# cur_best_epoch 0
# cur_best_auc: 0.772125322997416
# cur_best_epoch 1
# cur_best_auc: 0.8073320413436693
# cur_best_epoch 3
# cur_best_auc: 0.8246124031007752
# cur_best_epoch 8
# cur_best_auc: 0.8661175710594314
# cur_best_epoch 9
# cur_best_auc: 0.8680555555555555
# cur_best_epoch 15
# cur_best_auc: 0.8803294573643411
# cur_best_epoch 17
# ...

# %%
# !python train_and_eval_pytorch.py \
    --data_flag synapsemnist3d \
    --output_root ./output/synapsemnist3d_run3 \
    --num_epochs 30 \
    --batch_size 16 \
    --download \
    --model_flag resnet50 \
    --run run3
# Out:
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# ==> Building and training model...
# cur_best_auc: 0.5899547803617571
# cur_best_epoch 0
# cur_best_auc: 0.7283591731266149
# cur_best_epoch 1
# cur_best_auc: 0.7462855297157623
# cur_best_epoch 15
# synapsemnist3d
# train  auc: 0.99998  acc: 0.99756
# val  auc: 0.74629  acc: 0.76836
# test  auc: 0.69951  acc: 0.72159
# ...
# 100%|##########| 30/30 [44:22<00:00, 88.76s/it]

# %%
# !python train_and_eval_pytorch.py \
    --data_flag synapsemnist3d \
    --output_root ./output/synapsemnist3d_run5 \
    --num_epochs 30 \
    --batch_size 16 \
    --download \
    --model_flag resnet50 \
    --run run5
# Out:
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# ==> Building and training model...
# cur_best_auc: 0.7514534883720931
# cur_best_epoch 0
# cur_best_auc: 0.8020025839793282
# cur_best_epoch 4
# synapsemnist3d
# train  auc: 0.89878  acc: 0.84878
# val  auc: 0.80200  acc: 0.78531
# test  auc: 0.82007  acc: 0.80114
# ...
# 100%|##########| 30/30 [45:49<00:00, 91.64s/it]

# %%
# !python train_and_eval_pytorch.py \
    --data_flag synapsemnist3d \
    --output_root ./output/synapsemnist3d_run6 \
    --num_epochs 30 \
    --batch_size 16 \
    --download \
    --model_flag resnet50 \
    --run run6
# Out:
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# ==> Building and training model...
# cur_best_auc: 0.570736434108527
# cur_best_epoch 0
# cur_best_auc: 0.7013888888888888
# cur_best_epoch 1
# cur_best_auc: 0.7609819121447029
# cur_best_epoch 4
# synapsemnist3d
# train  auc: 0.99723  acc: 0.94065
# val  auc: 0.76098  acc: 0.70621
# test  auc: 0.73914  acc: 0.70170
# ...
# 100%|##########| 30/30 [44:28<00:00, 88.95s/it]

# %%
# !python train_and_eval_pytorch.py \
    --data_flag synapsemnist3d \
    --output_root ./output/synapsemnist3d_run7 \
    --num_epochs 30 \
    --batch_size 16 \
    --download \
    --model_flag resnet50 \
    --run run7
# Out:
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# ==> Building and training model...
# cur_best_auc: 0.6430878552971576
# cur_best_epoch 0
# cur_best_auc: 0.7269056847545219
# cur_best_epoch 2
# cur_best_auc: 0.7509689922480619
# cur_best_epoch 3
# cur_best_auc: 0.7978036175710594
# cur_best_epoch 4
# cur_best_auc: 0.8049903100775194
# cur_best_epoch 17
# synapsemnist3d
# train  auc: 1.00000  acc: 1.00000
# val  auc: 0.80499  acc: 0.79661
# test  auc: 0.74454  acc: 0.74716
# ...

# %%
# !python train_and_eval_pytorch.py \
    --data_flag synapsemnist3d \
    --output_root ./output/synapsemnist3d_run2 \
    --num_epochs 10 \
    --batch_size 32 \
    --download \
    --model_flag resnet50 \
    --run run2
