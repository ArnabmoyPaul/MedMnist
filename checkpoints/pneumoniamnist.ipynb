# %%
import torch
print(f"✓ GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")

# Clone repository
# !git clone https://github.com/MedMNIST/experiments.git
# %cd experiments

# Install ALL required dependencies (including acsconv for 3D models)
# !pip install -q medmnist tqdm
# !pip install -q acsconv

print("\n✓ Setup Complete with acsconv!")
# Out:
# ✓ GPU: Tesla T4
# Cloning into 'experiments'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 89 (delta 15), reused 11 (delta 11), pack-reused 67 (from 1)
# Receiving objects: 100% (89/89), 36.99 KiB | 18.50 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/experiments
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.8 MB/s eta 0:00:00
# ...
#
# ✓ Setup Complete with acsconv!

# %%
# !pip install -q git+https://github.com/M3DV/ACSConv.git
# Out:
#   Preparing metadata (setup.py) ... done

# %%
ls
# Out:
# LICENSE  MedMNIST2D/  MedMNIST3D/  README.md

# %%
# %cd MedMNIST2D/
# Out:
# /content/experiments/MedMNIST2D

# %%
# !python train_and_eval_pytorch.py \
  --data_flag pneumoniamnist \
  --output_root ./output/pneumoniamnist_run1_e5 \
  --num_epochs 5 \
  --batch_size 128 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run1
# Out:
# ==> Preparing data...
# 100% 4.17M/4.17M [00:01<00:00, 3.39MB/s]
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9104541559554412
# cur_best_epoch 0
#  20% 1/5 [00:18<01:12, 18.20s/it]cur_best_auc: 0.9896791392935352
# cur_best_epoch 1
#  60% 3/5 [00:52<00:34, 17.24s/it]cur_best_auc: 0.993620870227554
# cur_best_epoch 3
#  80% 4/5 [01:09<00:17, 17.37s/it]cur_best_auc: 0.99371608111968
# cur_best_epoch 4
# 100% 5/5 [01:27<00:00, 17.47s/it]
# pneumoniamnist
# train  auc: 0.99788  acc: 0.97196
# val  auc: 0.99372  acc: 0.95229
# test  auc: 0.93760  acc: 0.85897

# %%
# !python train_and_eval_pytorch.py \
  --data_flag pneumoniamnist \
  --output_root ./output/pneumoniamnist_run2_e5 \
  --num_epochs 5 \
  --batch_size 128 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run2
# Out:
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9231076835189944
# cur_best_epoch 0
#  20% 1/5 [00:17<01:10, 17.57s/it]cur_best_auc: 0.9927830143768446
# cur_best_epoch 1
# 100% 5/5 [01:27<00:00, 17.50s/it]
# pneumoniamnist
# train  auc: 0.99574  acc: 0.96240
# val  auc: 0.99278  acc: 0.95229
# test  auc: 0.96137  acc: 0.88141

# %%
# !python train_and_eval_pytorch.py \
  --data_flag pneumoniamnist \
  --output_root ./output/pneumoniamnist_run3_e5 \
  --num_epochs 5 \
  --batch_size 128 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run3
# Out:
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.8392364086451489
# cur_best_epoch 0
#  20% 1/5 [00:17<01:11, 17.88s/it]cur_best_auc: 0.9915071884223555
# cur_best_epoch 1
#  40% 2/5 [00:35<00:53, 17.71s/it]cur_best_auc: 0.9929353518042465
# cur_best_epoch 2
# 100% 5/5 [01:27<00:00, 17.53s/it]
# pneumoniamnist
# train  auc: 0.99710  acc: 0.95497
# val  auc: 0.99294  acc: 0.95611
# test  auc: 0.95920  acc: 0.79006

# %%
# !python train_and_eval_pytorch.py \
  --data_flag pneumoniamnist \
  --output_root ./output/pneumoniamnist_run4_e5 \
  --num_epochs 5 \
  --batch_size 128 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run4
# Out:
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9359516328667999
# cur_best_epoch 0
#  20% 1/5 [00:17<01:10, 17.65s/it]cur_best_auc: 0.9917737789203085
# cur_best_epoch 1
#  60% 3/5 [00:53<00:35, 17.69s/it]cur_best_auc: 0.9941350090450347
# cur_best_epoch 3
# 100% 5/5 [01:27<00:00, 17.52s/it]
# pneumoniamnist
# train  auc: 0.99574  acc: 0.96623
# val  auc: 0.99414  acc: 0.96374
# test  auc: 0.94644  acc: 0.87500

# %%
# !python train_and_eval_pytorch.py \
  --data_flag pneumoniamnist \
  --output_root ./output/pneumoniamnist_run5_e5 \
  --num_epochs 5 \
  --batch_size 128 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run5
# Out:
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9466723793201942
# cur_best_epoch 0
#  20% 1/5 [00:17<01:11, 17.95s/it]cur_best_auc: 0.9858516614300675
# cur_best_epoch 1
#  40% 2/5 [00:35<00:53, 17.78s/it]cur_best_auc: 0.9904408264305437
# cur_best_epoch 2
# 100% 5/5 [01:27<00:00, 17.58s/it]
# pneumoniamnist
# train  auc: 0.99803  acc: 0.97727
# val  auc: 0.99044  acc: 0.95992
# test  auc: 0.95992  acc: 0.88141

# %%
# !python train_and_eval_pytorch.py \
  --data_flag pneumoniamnist \
  --output_root ./output/pneumoniamnist_run1_e5 \
  --num_epochs 5 \
  --batch_size 128 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run-1
# Out:
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9010092354565363
# cur_best_epoch 0
#  20% 1/5 [00:17<01:10, 17.73s/it]cur_best_auc: 0.9858135770732172
# cur_best_epoch 1
#  40% 2/5 [00:35<00:53, 17.69s/it]cur_best_auc: 0.9937732076549557
# cur_best_epoch 2
# 100% 5/5 [01:27<00:00, 17.57s/it]
# pneumoniamnist
# train  auc: 0.99835  acc: 0.98003
# val  auc: 0.99377  acc: 0.96565
# test  auc: 0.95392  acc: 0.81090

# %%
# !python train_and_eval_pytorch.py \
  --data_flag pneumoniamnist \
  --output_root ./output/pneumoniamnist_run11_e5 \
  --num_epochs 5 \
  --batch_size 128 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run11
# Out:
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9226506712367896
# cur_best_epoch 0
#  20% 1/5 [00:17<01:10, 17.62s/it]cur_best_auc: 0.9911263448538512
# cur_best_epoch 1
#  40% 2/5 [00:35<00:53, 17.77s/it]cur_best_auc: 0.9939826716176331
# cur_best_epoch 2
# 100% 5/5 [01:27<00:00, 17.53s/it]
# pneumoniamnist
# train  auc: 0.99822  acc: 0.98237
# val  auc: 0.99398  acc: 0.96947
# test  auc: 0.95523  acc: 0.86699
