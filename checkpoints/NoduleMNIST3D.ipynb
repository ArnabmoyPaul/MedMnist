# %%
# !pip install medmnist
# !pip install torch torchvision
# !pip install tensorboardX
# !pip install tqdm
# !pip install git+https://github.com/M3DV/ACSConv.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.0 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/M3DV/ACSConv.git to /tmp/pip-req-build-r074hphk
#   Running command git clone --filter=blob:none --quiet https://github.com/M3DV/ACSConv.git /tmp/pip-req-build-r074hphk
#   Resolved https://github.com/M3DV/ACSConv.git to commit d1d60c83f4503c5a83aeecf7f816983351a7fa7f
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ACSConv: filename=ACSConv-0.1.1-py3-none-any.whl size=26976 sha256=5e1e7666fdb448d9b9f0c4fe78b60e1c4eaab2675b3e1fdc3eadeddbf650c40e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dgm97enw/wheels/9b/f1/c9/cd0ddaa32d58a56e954d28b4684812a3c262213ddc4a85dc94
# Successfully built ACSConv
# ...

# %%
# !git clone https://github.com/MedMNIST/experiments.git
# Out:
# Cloning into 'experiments'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 89 (delta 15), reused 11 (delta 11), pack-reused 67 (from 1)
# Receiving objects: 100% (89/89), 36.99 KiB | 5.28 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# Corrected training code for NoduleMNIST3D dataset
# %cd experiments/MedMNIST3D

# !python train_and_eval_pytorch.py \
    --data_flag nodulemnist3d \
    --output_root ./output/nodulemnist3d_run1 \
    --num_epochs 5 \
    --batch_size 16 \
    --model_flag resnet50 \
    --download \
    --run run1
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST3D'
# /content/experiments/MedMNIST3D
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.5491676345334882
# cur_best_epoch 0
#  20% 1/5 [01:48<07:14, 108.56s/it]cur_best_auc: 0.7810685249709641
# cur_best_epoch 1
#  40% 2/5 [03:40<05:32, 110.73s/it]cur_best_auc: 0.8416569879984515
# cur_best_epoch 2
# 100% 5/5 [09:17<00:00, 111.52s/it]
# nodulemnist3d
# train  auc: 0.83659  acc: 0.84197
# val  auc: 0.84166  acc: 0.83636
# test  auc: 0.84559  acc: 0.85161

# %%
# %cd experiments/MedMNIST3D

# !python train_and_eval_pytorch.py \
    --data_flag nodulemnist3d \
    --output_root ./output/nodulemnist3d_run1 \
    --num_epochs 5 \
    --batch_size 16 \
    --model_flag resnet50 \
    --download \
    --run run2
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST3D'
# /content/experiments/MedMNIST3D
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.7506775067750677
# cur_best_epoch 0
#  20% 1/5 [01:50<07:23, 110.77s/it]cur_best_auc: 0.8215253581107239
# cur_best_epoch 1
#  80% 4/5 [07:26<01:51, 111.90s/it]cur_best_auc: 0.8881145954316686
# cur_best_epoch 4
# 100% 5/5 [09:18<00:00, 111.80s/it]
# nodulemnist3d
# train  auc: 0.88241  acc: 0.84715
# val  auc: 0.88811  acc: 0.87879
# test  auc: 0.88720  acc: 0.85484

# %%
# %cd experiments/MedMNIST3D

# !python train_and_eval_pytorch.py \
    --data_flag nodulemnist3d \
    --output_root ./output/nodulemnist3d_run1 \
    --num_epochs 5 \
    --batch_size 16 \
    --model_flag resnet50 \
    --download \
    --run run3
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST3D'
# /content/experiments/MedMNIST3D
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.7357723577235772
# cur_best_epoch 0
#  20% 1/5 [01:52<07:31, 112.98s/it]cur_best_auc: 0.8356562137049941
# cur_best_epoch 1
#  40% 2/5 [03:45<05:37, 112.61s/it]cur_best_auc: 0.8788230739450252
# cur_best_epoch 2
# 100% 5/5 [09:21<00:00, 112.40s/it]
# nodulemnist3d
# train  auc: 0.85291  acc: 0.82297
# val  auc: 0.87882  acc: 0.83636
# test  auc: 0.84388  acc: 0.84194

# %%
# %cd experiments/MedMNIST3D

# !python train_and_eval_pytorch.py \
    --data_flag nodulemnist3d \
    --output_root ./output/nodulemnist3d_run1 \
    --num_epochs 5 \
    --batch_size 16 \
    --model_flag resnet50 \
    --download \
    --run run4
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST3D'
# /content/experiments/MedMNIST3D
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.6732481610530391
# cur_best_epoch 0
#  40% 2/5 [03:45<05:37, 112.57s/it]cur_best_auc: 0.7603561749903213
# cur_best_epoch 2
#  60% 3/5 [05:37<03:44, 112.45s/it]cur_best_auc: 0.8298490127758421
# cur_best_epoch 3
#  80% 4/5 [07:29<01:52, 112.37s/it]cur_best_auc: 0.8813395276809911
# cur_best_epoch 4
# 100% 5/5 [09:21<00:00, 112.39s/it]
# nodulemnist3d
# train  auc: 0.82905  acc: 0.83765
# val  auc: 0.88134  acc: 0.87879
# test  auc: 0.79287  acc: 0.82903

# %%
# %cd experiments/MedMNIST3D

# !python train_and_eval_pytorch.py \
    --data_flag nodulemnist3d \
    --output_root ./output/nodulemnist3d_run1 \
    --num_epochs 5 \
    --batch_size 16 \
    --model_flag resnet50 \
    --download \
    --run run5
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST3D'
# /content/experiments/MedMNIST3D
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.6831204026325978
# cur_best_epoch 0
#  20% 1/5 [01:52<07:31, 112.89s/it]cur_best_auc: 0.8193960511033681
# cur_best_epoch 1
#  60% 3/5 [05:37<03:44, 112.43s/it]cur_best_auc: 0.8497870692992644
# cur_best_epoch 3
# 100% 5/5 [09:21<00:00, 112.34s/it]
# nodulemnist3d
# train  auc: 0.86450  acc: 0.84197
# val  auc: 0.84979  acc: 0.83636
# test  auc: 0.86090  acc: 0.84839

# %%
# !python train_and_eval_pytorch.py \
    --data_flag nodulemnist3d \
    --output_root ./output/nodulemnist3d_run6_e100 \
    --num_epochs 25 \
    --batch_size 32 \
    --download \
    --model_flag resnet50 \
    --run run6
# Out:
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# 100% 29.3M/29.3M [00:16<00:00, 1.76MB/s]
# ==> Building and training model...
#   0% 0/25 [00:00<?, ?it/s]cur_best_auc: 0.5871080139372822
# cur_best_epoch 0
#   4% 1/25 [01:08<27:15, 68.13s/it]cur_best_auc: 0.748548199767712
# cur_best_epoch 1
#   8% 2/25 [02:16<26:04, 68.01s/it]cur_best_auc: 0.8420441347270616
# cur_best_epoch 2
#  16% 4/25 [04:32<23:52, 68.23s/it]cur_best_auc: 0.8604336043360433
# cur_best_epoch 4
#  24% 6/25 [06:49<21:38, 68.33s/it]cur_best_auc: 0.8685636856368564
# cur_best_epoch 6
#  28% 7/25 [07:57<20:30, 68.36s/it]cur_best_auc: 0.8931475029036005
# cur_best_epoch 7
#  80% 20/25 [22:47<05:41, 68.39s/it]cur_best_auc: 0.8939217963608208
# cur_best_epoch 20
# 100% 25/25 [28:29<00:00, 68.36s/it]
# nodulemnist3d
# train  auc: 0.95199  acc: 0.85492
# ...
