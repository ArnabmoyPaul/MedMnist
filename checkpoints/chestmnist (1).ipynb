# %%
# !pip install torch torchvision medmnist tqdm tensorboardX
# !pip install git+https://github.com/M3DV/ACSConv.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 12.9 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/M3DV/ACSConv.git to /tmp/pip-req-build-dypi8hmv
#   Running command git clone --filter=blob:none --quiet https://github.com/M3DV/ACSConv.git /tmp/pip-req-build-dypi8hmv
#   Resolved https://github.com/M3DV/ACSConv.git to commit d1d60c83f4503c5a83aeecf7f816983351a7fa7f
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ACSConv: filename=ACSConv-0.1.1-py3-none-any.whl size=26976 sha256=b0dfe0ec3c928410ee8aae664e375ae77eda3fc7e51cfd59d20c7352909d7024
#   Stored in directory: /tmp/pip-ephem-wheel-cache-07rs9m74/wheels/9b/f1/c9/cd0ddaa32d58a56e954d28b4684812a3c262213ddc4a85dc94
# Successfully built ACSConv
# ...

# %%
# !git clone https://github.com/MedMNIST/experiments.git
# Out:
# Cloning into 'experiments'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 89 (delta 15), reused 11 (delta 11), pack-reused 67 (from 1)
# Receiving objects: 100% (89/89), 36.99 KiB | 621.00 KiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# %cd /content/experiments/MedMNIST2D
# Out:
# /content/experiments/MedMNIST2D

# %%
# !python train_and_eval_pytorch.py \
  --data_flag chestmnist \
  --output_root ./output/chestmnist_run1_e100 \
  --num_epochs 100 \
  --batch_size 128 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run1
# Out:
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/100 [00:00<?, ?it/s]cur_best_auc: 0.6946417915826927
# cur_best_epoch 0
#   1% 1/100 [01:07<1:52:05, 67.93s/it]cur_best_auc: 0.7320884768438917
# cur_best_epoch 1
#   4% 4/100 [04:28<1:47:24, 67.13s/it]cur_best_auc: 0.7521514103626908
# cur_best_epoch 4
#   5% 5/100 [05:36<1:46:16, 67.13s/it]cur_best_auc: 0.7624738158053456
# cur_best_epoch 5
#   9% 9/100 [10:03<1:41:34, 66.97s/it]cur_best_auc: 0.7639001649173606
# cur_best_epoch 9
#  10% 10/100 [11:10<1:40:27, 66.98s/it]cur_best_auc: 0.7657179681172799
# cur_best_epoch 10
#  11% 11/100 [12:17<1:39:21, 66.98s/it]cur_best_auc: 0.7715359235487206
# cur_best_epoch 11
#  28% 28/100 [31:15<1:20:08, 66.78s/it]Exception ignored in: <generator object tqdm.__iter__ at 0x7b4739e80b80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1196, in __iter__
#     self.close()
# ...

# %%
# !python train_and_eval_pytorch.py \
  --data_flag chestmnist \
  --output_root ./output/chestmnist_run1_e100 \
  --num_epochs 15 \
  --batch_size 128 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run1
# Out:
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/15 [00:00<?, ?it/s]cur_best_auc: 0.6737364273782773
# cur_best_epoch 0
#   7% 1/15 [01:06<15:36, 66.90s/it]cur_best_auc: 0.6798960766619213
# cur_best_epoch 1
#  13% 2/15 [02:13<14:27, 66.72s/it]cur_best_auc: 0.7252685407384816
# cur_best_epoch 2
#  20% 3/15 [03:19<13:17, 66.49s/it]cur_best_auc: 0.7531668608670189
# cur_best_epoch 3
#  47% 7/15 [07:44<08:50, 66.32s/it]cur_best_auc: 0.7584662965379285
# cur_best_epoch 7
#  53% 8/15 [08:51<07:44, 66.34s/it]cur_best_auc: 0.7633949815467723
# cur_best_epoch 8
#  60% 9/15 [09:57<06:37, 66.30s/it]cur_best_auc: 0.7707819718857646
# cur_best_epoch 9
# 100% 15/15 [16:37<00:00, 66.47s/it]
# chestmnist
# train  auc: 0.80732  acc: 0.94877
# val  auc: 0.77078  acc: 0.94798
# test  auc: 0.76993  acc: 0.94679

# %%
# !python train_and_eval_pytorch.py \
  --data_flag chestmnist \
  --output_root ./output/chestmnist_run2_e100 \
  --num_epochs 15 \
  --batch_size 128 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run2
# Out:
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/15 [00:00<?, ?it/s]cur_best_auc: 0.6923761392171287
# cur_best_epoch 0
#  13% 2/15 [02:15<14:37, 67.54s/it]cur_best_auc: 0.6997257875249187
# cur_best_epoch 2
#  20% 3/15 [03:22<13:28, 67.38s/it]cur_best_auc: 0.7293838548819307
# cur_best_epoch 3
#  27% 4/15 [04:29<12:18, 67.14s/it]cur_best_auc: 0.7326383112013203
# cur_best_epoch 4
#  33% 5/15 [05:35<11:10, 67.03s/it]cur_best_auc: 0.7436965856621114
# cur_best_epoch 5
#  40% 6/15 [06:42<10:02, 66.97s/it]cur_best_auc: 0.7647336136211564
# cur_best_epoch 6
#  53% 8/15 [08:56<07:47, 66.80s/it]cur_best_auc: 0.7651153586126592
# cur_best_epoch 8
#  73% 11/15 [12:16<04:27, 66.85s/it]cur_best_auc: 0.7700559671617755
# cur_best_epoch 11
# 100% 15/15 [16:43<00:00, 66.93s/it]
# chestmnist
# train  auc: 0.82133  acc: 0.94919
# val  auc: 0.77006  acc: 0.94821
# test  auc: 0.76913  acc: 0.94645

# %%
# !python train_and_eval_pytorch.py \
  --data_flag chestmnist \
  --output_root ./output/chestmnist_run3_e100 \
  --num_epochs 15 \
  --batch_size 64 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run3
# Out:
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/15 [00:00<?, ?it/s]cur_best_auc: 0.6237487941993006
# cur_best_epoch 0
#   7% 1/15 [01:20<18:44, 80.32s/it]cur_best_auc: 0.7048176619391352
# cur_best_epoch 1
#  20% 3/15 [03:59<15:58, 79.89s/it]cur_best_auc: 0.7389099246061861
# cur_best_epoch 3
#  27% 4/15 [05:19<14:38, 79.82s/it]cur_best_auc: 0.7546304959958255
# cur_best_epoch 4
#  40% 6/15 [07:58<11:56, 79.65s/it]cur_best_auc: 0.7656398344351182
# cur_best_epoch 6
#  60% 9/15 [11:58<07:58, 79.78s/it]cur_best_auc: 0.7672213111008166
# cur_best_epoch 9
#  80% 12/15 [15:57<03:59, 79.74s/it]cur_best_auc: 0.769804126365499
# cur_best_epoch 12
# 100% 15/15 [19:55<00:00, 79.72s/it]
# chestmnist
# train  auc: 0.85510  acc: 0.95139
# val  auc: 0.76980  acc: 0.94847
# test  auc: 0.77161  acc: 0.94743

# %%
# !python train_and_eval_pytorch.py \
  --data_flag chestmnist \
  --output_root ./output/chestmnist_run4_e15 \
  --num_epochs 15 \
  --batch_size 32 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run4
# Out:
# ==> Preparing data...
# 100% 82.8M/82.8M [00:34<00:00, 2.42MB/s]
# ==> Building and training model...
#   0% 0/15 [00:00<?, ?it/s]cur_best_auc: 0.6598812231811764
# cur_best_epoch 0
#  13% 2/15 [05:13<33:58, 156.81s/it]cur_best_auc: 0.7066643501612598
# cur_best_epoch 2
#  20% 3/15 [07:50<31:25, 157.16s/it]cur_best_auc: 0.7215039330897575
# cur_best_epoch 3
#  27% 4/15 [10:28<28:51, 157.39s/it]cur_best_auc: 0.7456107305608215
# cur_best_epoch 4
#  33% 5/15 [13:06<26:15, 157.56s/it]cur_best_auc: 0.7523262662576417
# cur_best_epoch 5
#  40% 6/15 [15:44<23:38, 157.66s/it]cur_best_auc: 0.7591847093036288
# cur_best_epoch 6
#  47% 7/15 [18:22<21:01, 157.68s/it]cur_best_auc: 0.7669260271801865
# cur_best_epoch 7
#  67% 10/15 [26:15<13:08, 157.71s/it]cur_best_auc: 0.7675672156206489
# cur_best_epoch 10
# 100% 15/15 [39:23<00:00, 157.54s/it]
# chestmnist
# train  auc: 0.82653  acc: 0.95035
# val  auc: 0.76757  acc: 0.94914
# test  auc: 0.77325  acc: 0.94745

# %%
# !python train_and_eval_pytorch.py \
  --data_flag chestmnist \
  --output_root ./output/chestmnist_run5_e15 \
  --num_epochs 15 \
  --batch_size 16 \
  --model_flag resnet50 \
  --as_rgb \
  --download \
  --run run5
# Out:
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/15 [00:00<?, ?it/s]cur_best_auc: 0.6397425854917529
# cur_best_epoch 0
#   7% 1/15 [03:27<48:21, 207.23s/it]cur_best_auc: 0.6817070006895402
# cur_best_epoch 1
#  13% 2/15 [06:54<44:54, 207.29s/it]cur_best_auc: 0.7138164714053926
# cur_best_epoch 2
#  20% 3/15 [10:22<41:30, 207.50s/it]cur_best_auc: 0.7234674872481219
# cur_best_epoch 3
#  27% 4/15 [13:50<38:05, 207.76s/it]cur_best_auc: 0.7393719309152866
# cur_best_epoch 4
#  33% 5/15 [17:18<34:39, 207.95s/it]cur_best_auc: 0.7463209374678483
# cur_best_epoch 5
#  40% 6/15 [20:46<31:10, 207.79s/it]cur_best_auc: 0.7552285540329835
# cur_best_epoch 6
#  47% 7/15 [24:14<27:42, 207.83s/it]cur_best_auc: 0.7582144604759797
# cur_best_epoch 7
#  53% 8/15 [27:43<24:17, 208.17s/it]cur_best_auc: 0.761070763365706
# cur_best_epoch 8
#  60% 9/15 [31:11<20:50, 208.36s/it]cur_best_auc: 0.7628187756659074
# cur_best_epoch 9
# 100% 15/15 [52:03<00:00, 208.23s/it]
# chestmnist
# ...
