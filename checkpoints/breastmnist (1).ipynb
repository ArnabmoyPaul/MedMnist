# %%
# !pip install medmnist
# !pip install torch torchvision
# !pip install tensorboardX
# !pip install tqdm
# !pip install git+https://github.com/M3DV/ACSConv.git

# %%
# !pip install medmnist
# !pip install torch torchvision
# !pip install tensorboardX
# !pip install tqdm
# !pip install git+https://github.com/M3DV/ACSConv.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.5 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/M3DV/ACSConv.git to /tmp/pip-req-build-20exok81
#   Running command git clone --filter=blob:none --quiet https://github.com/M3DV/ACSConv.git /tmp/pip-req-build-20exok81
#   Resolved https://github.com/M3DV/ACSConv.git to commit d1d60c83f4503c5a83aeecf7f816983351a7fa7f
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ACSConv: filename=ACSConv-0.1.1-py3-none-any.whl size=26976 sha256=1f5fc90f5c8c27727561ee64d1e70916aa22f4ad8e54c85cbad83c620251bb97
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wt1ubn91/wheels/9b/f1/c9/cd0ddaa32d58a56e954d28b4684812a3c262213ddc4a85dc94
# Successfully built ACSConv
# ...

# %%
# !git clone https://github.com/MedMNIST/experiments.git

# %%
# %cd experiments/MedMNIST2D

# Run training for breastmnist dataset with output saved separately
# !python train_and_eval_pytorch.py \
    --data_flag breastmnist \
    --output_root ./output/breastmnist_run1 \
    --num_epochs 20 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run1
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/20 [00:00<?, ?it/s]cur_best_auc: 0.5396825396825397
# cur_best_epoch 0
#   5% 1/20 [00:08<02:45,  8.72s/it]cur_best_auc: 0.617376775271512
# cur_best_epoch 1
#  10% 2/20 [00:17<02:32,  8.50s/it]cur_best_auc: 0.6633249791144529
# cur_best_epoch 2
#  45% 9/20 [01:18<01:36,  8.80s/it]cur_best_auc: 0.722639933166249
# ...

# %%
# %cd experiments/MedMNIST2D

# Run training for breastmnist dataset with output saved separately
# !python train_and_eval_pytorch.py \
    --data_flag breastmnist \
    --output_root ./output/breastmnist_run1 \
    --num_epochs 20 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run2
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/20 [00:00<?, ?it/s]cur_best_auc: 0.38680033416875526
# cur_best_epoch 0
#   5% 1/20 [00:09<02:52,  9.07s/it]cur_best_auc: 0.5864661654135339
# cur_best_epoch 1
#  35% 7/20 [01:02<01:56,  8.92s/it]cur_best_auc: 0.6374269005847953
# cur_best_epoch 7
# ...

# %%
# %cd experiments/MedMNIST2D

# Run training for breastmnist dataset with output saved separately
# !python train_and_eval_pytorch.py \
    --data_flag breastmnist \
    --output_root ./output/breastmnist_run1 \
    --num_epochs 20 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run3
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/20 [00:00<?, ?it/s]cur_best_auc: 0.5722639933166249
# cur_best_epoch 0
#  25% 5/20 [00:44<02:13,  8.90s/it]cur_best_auc: 0.5973266499582289
# cur_best_epoch 5
#  30% 6/20 [00:53<02:04,  8.87s/it]cur_best_auc: 0.6131996658312447
# cur_best_epoch 6
#  35% 7/20 [01:02<01:54,  8.84s/it]cur_best_auc: 0.731829573934837
# ...

# %%
# %cd experiments/MedMNIST2D

# Run training for breastmnist dataset with output saved separately
# !python train_and_eval_pytorch.py \
    --data_flag breastmnist \
    --output_root ./output/breastmnist_run1 \
    --num_epochs 20 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run4
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/20 [00:00<?, ?it/s]cur_best_auc: 0.3943191311612364
# cur_best_epoch 0
#   5% 1/20 [00:09<02:55,  9.26s/it]cur_best_auc: 0.5371762740183793
# cur_best_epoch 1
#  25% 5/20 [00:44<02:13,  8.88s/it]cur_best_auc: 0.5388471177944862
# cur_best_epoch 5
# ...

# %%
# %cd experiments/MedMNIST2D

# Run training for breastmnist dataset with output saved separately
# !python train_and_eval_pytorch.py \
    --data_flag breastmnist \
    --output_root ./output/breastmnist_run1 \
    --num_epochs 20 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run5
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/20 [00:00<?, ?it/s]cur_best_auc: 0.3751044277360067
# cur_best_epoch 0
#  10% 2/20 [00:18<02:41,  8.98s/it]cur_best_auc: 0.3834586466165414
# cur_best_epoch 2
#  20% 4/20 [00:35<02:21,  8.87s/it]cur_best_auc: 0.4611528822055138
# cur_best_epoch 4
# ...
