# %%
# !pip install torch torchvision medmnist tqdm tensorboardX
# !pip install git+https://github.com/M3DV/ACSConv.git
# !git clone https://github.com/MedMNIST/experiments.git
# %cd /content/experiments/
# %cd /content/experiments/MedMNIST2D
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 12.1 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/M3DV/ACSConv.git to /tmp/pip-req-build-wuqnq1k6
#   Running command git clone --filter=blob:none --quiet https://github.com/M3DV/ACSConv.git /tmp/pip-req-build-wuqnq1k6
#   Resolved https://github.com/M3DV/ACSConv.git to commit d1d60c83f4503c5a83aeecf7f816983351a7fa7f
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ACSConv: filename=ACSConv-0.1.1-py3-none-any.whl size=26976 sha256=1965238c9b3c1884f014c0871bc508cf7e86971fd0cb405405fa7b77cd5ca5cd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k47bd16g/wheels/9b/f1/c9/cd0ddaa32d58a56e954d28b4684812a3c262213ddc4a85dc94
# Successfully built ACSConv
# ...
# Cloning into 'experiments'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (11/11), done.
# ...

# %%
# %cd experiments/MedMNIST2D

# Run training for organamnist dataset with output saved separately
# !python train_and_eval_pytorch.py \
    --data_flag organamnist \
    --output_root ./output/organamnist_run1 \
    --num_epochs 5 \
    --batch_size 64 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run1
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# 100% 38.2M/38.2M [00:36<00:00, 1.04MB/s]
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9960884394606164
# cur_best_epoch 0
#  20% 1/5 [09:36<38:27, 576.88s/it]cur_best_auc: 0.9990326201104321
# cur_best_epoch 1
#  40% 2/5 [19:17<28:57, 579.05s/it]cur_best_auc: 0.9996195682337852
# cur_best_epoch 2
# ...

# %%
# %cd experiments/MedMNIST2D

# Run training for organamnist dataset with output saved separately
# !python train_and_eval_pytorch.py \
    --data_flag organamnist \
    --output_root ./output/organamnist_run2 \
    --num_epochs 5 \
    --batch_size 64 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run2
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# 100% 38.2M/38.2M [00:36<00:00, 1.04MB/s]
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9960884394606164
# cur_best_epoch 0
#  20% 1/5 [09:36<38:27, 576.88s/it]cur_best_auc: 0.9990326201104321
# cur_best_epoch 1
#  40% 2/5 [19:17<28:57, 579.05s/it]cur_best_auc: 0.9996195682337852
# cur_best_epoch 2
# ...

# %%
# %cd experiments/MedMNIST2D

# Run training for organamnist dataset with output saved separately
# !python train_and_eval_pytorch.py \
    --data_flag organamnist \
    --output_root ./output/organamnist_run3 \
    --num_epochs 5 \
    --batch_size 64 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run3
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# 100% 38.2M/38.2M [00:51<00:00, 744kB/s]
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9541986429581997
# cur_best_epoch 0
#  20% 1/5 [09:23<37:35, 563.80s/it]cur_best_auc: 0.9983274466766626
# cur_best_epoch 1
#  40% 2/5 [18:48<28:12, 564.12s/it]cur_best_auc: 0.9994901907019744
# cur_best_epoch 2
# ...

# %%
# %cd experiments/MedMNIST2D

# Run training for organamnist dataset with output saved separately
# !python train_and_eval_pytorch.py \
    --data_flag organamnist \
    --output_root ./output/organamnist_run4 \
    --num_epochs 5 \
    --batch_size 64 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run4
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# 100% 38.2M/38.2M [00:36<00:00, 1.04MB/s]
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9960884394606164
# cur_best_epoch 0
#  20% 1/5 [09:36<38:27, 576.88s/it]cur_best_auc: 0.9990326201104321
# cur_best_epoch 1
#  40% 2/5 [19:17<28:57, 579.05s/it]cur_best_auc: 0.9996195682337852
# cur_best_epoch 2
# ...

# %%
# %cd experiments/MedMNIST2D

# Run training for organamnist dataset with output saved separately
# !python train_and_eval_pytorch.py \
    --data_flag organamnist \
    --output_root ./output/organamnist_run5 \
    --num_epochs 5 \
    --batch_size 64 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run5
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9948230523729531
# cur_best_epoch 0
#  20% 1/5 [09:24<37:37, 564.46s/it]cur_best_auc: 0.9989079500521574
# cur_best_epoch 1
#  60% 3/5 [28:11<18:47, 563.72s/it]cur_best_auc: 0.9992647041521615
# cur_best_epoch 3
# 100% 5/5 [46:57<00:00, 563.43s/it]
# organamnist
# ...
