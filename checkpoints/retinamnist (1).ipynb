# %%
# !pip install medmnist
# !pip install torch torchvision
# !pip install tensorboardX
# !pip install tqdm
# !pip install git+https://github.com/M3DV/ACSConv.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.1 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/M3DV/ACSConv.git to /tmp/pip-req-build-xujhbuwi
#   Running command git clone --filter=blob:none --quiet https://github.com/M3DV/ACSConv.git /tmp/pip-req-build-xujhbuwi
#   Resolved https://github.com/M3DV/ACSConv.git to commit d1d60c83f4503c5a83aeecf7f816983351a7fa7f
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ACSConv: filename=ACSConv-0.1.1-py3-none-any.whl size=26976 sha256=1a4ae7e66f5c5e9cb822e2eda55d46bebfa19f8b1dcd837d9e2c6ad2672cb456
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kn40rm6y/wheels/9b/f1/c9/cd0ddaa32d58a56e954d28b4684812a3c262213ddc4a85dc94
# Successfully built ACSConv
# ...

# %%
# !git clone https://github.com/MedMNIST/experiments.git
# Out:
# Cloning into 'experiments'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 89 (delta 15), reused 11 (delta 11), pack-reused 67 (from 1)
# Receiving objects: 100% (89/89), 36.99 KiB | 2.05 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# Change directory to MedMNIST2D folder
# %cd experiments/MedMNIST2D

# Training command for TissueMNIST, Run 1
# !python train_and_eval_pytorch.py \
    --data_flag retinamnist \
    --output_root ./output/retinamnist_run1 \
    --num_epochs 3 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run1
# Out:
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# 100% 3.29M/3.29M [00:05<00:00, 568kB/s]
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/3 [00:00<?, ?it/s]cur_best_auc: 0.5827216286580894
# cur_best_epoch 0
#  33% 1/3 [00:16<00:33, 16.74s/it]cur_best_auc: 0.720266947121867
# cur_best_epoch 1
#  67% 2/3 [00:32<00:16, 16.04s/it]cur_best_auc: 0.771760691363895
# cur_best_epoch 2
# 100% 3/3 [00:48<00:00, 16.02s/it]
# retinamnist
# train  auc: 0.74283  acc: 0.49630
# ...

# %%
# %cd experiments/MedMNIST2D

# Training command for TissueMNIST, Run 1
# !python train_and_eval_pytorch.py \
    --data_flag retinamnist \
    --output_root ./output/retinamnist_run2 \
    --num_epochs 3 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run2
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/3 [00:00<?, ?it/s]cur_best_auc: 0.6746025136035815
# cur_best_epoch 0
#  33% 1/3 [00:16<00:32, 16.22s/it]cur_best_auc: 0.740323192404962
# cur_best_epoch 1
#  67% 2/3 [00:31<00:15, 15.85s/it]cur_best_auc: 0.7819617187457004
# cur_best_epoch 2
# 100% 3/3 [00:47<00:00, 15.89s/it]
# retinamnist
# ...

# %%
# %cd experiments/MedMNIST2D

# Training command for TissueMNIST, Run 1
# !python train_and_eval_pytorch.py \
    --data_flag retinamnist \
    --output_root ./output/retinamnist_run3 \
    --num_epochs 3 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run3
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/3 [00:00<?, ?it/s]cur_best_auc: 0.5510341940343466
# cur_best_epoch 0
#  33% 1/3 [00:16<00:32, 16.19s/it]cur_best_auc: 0.6759074566815222
# cur_best_epoch 1
#  67% 2/3 [00:32<00:16, 16.10s/it]cur_best_auc: 0.7651442197574159
# cur_best_epoch 2
# 100% 3/3 [00:48<00:00, 16.13s/it]
# retinamnist
# ...

# %%
# %cd experiments/MedMNIST2D

# Training command for TissueMNIST, Run 1
# !python train_and_eval_pytorch.py \
    --data_flag retinamnist \
    --output_root ./output/retinamnist_run4 \
    --num_epochs 3 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run4
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/3 [00:00<?, ?it/s]cur_best_auc: 0.6272530770639084
# cur_best_epoch 0
#  33% 1/3 [00:16<00:33, 16.57s/it]cur_best_auc: 0.7042453533922641
# cur_best_epoch 1
#  67% 2/3 [00:32<00:16, 16.30s/it]cur_best_auc: 0.763401974229968
# cur_best_epoch 2
# 100% 3/3 [00:48<00:00, 16.25s/it]
# retinamnist
# ...

# %%
# %cd experiments/MedMNIST2D

# Training command for TissueMNIST, Run 1
# !python train_and_eval_pytorch.py \
    --data_flag retinamnist \
    --output_root ./output/retinamnist_run5 \
    --num_epochs 5 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run5
# Out:
# [Errno 2] No such file or directory: 'experiments/MedMNIST2D'
# /content/experiments/MedMNIST2D
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.4544190218262683
# cur_best_epoch 0
#  20% 1/5 [00:16<01:05, 16.36s/it]cur_best_auc: 0.5437559577468044
# cur_best_epoch 1
#  60% 3/5 [00:48<00:31, 15.94s/it]cur_best_auc: 0.7038356823107396
# cur_best_epoch 3
#  80% 4/5 [01:03<00:15, 15.92s/it]cur_best_auc: 0.7672698940661563
# ...
