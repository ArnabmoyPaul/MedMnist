# %%
# Cell 1: Test GPU
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

# Test tensor on GPU
x = torch.rand(5, 3).cuda()
print(f"\nTest tensor on GPU: {x.device}")
print("✓ GPU setup working!")
# Out:
# PyTorch version: 2.5.1
# CUDA available: True
# CUDA version: 12.1
# GPU: NVIDIA GeForce RTX 4060
# GPU Memory: 8.59 GB
#
# Test tensor on GPU: cuda:0
# ✓ GPU setup working!

# %%
# Navigate to your experiments folder
import os
os.chdir(r'C:\Users\User\Desktop\mnist\experiments\MedMNIST3D')
print(f"✓ Current directory: {os.getcwd()}")

# Verify GPU
import torch
print(f"✓ CUDA Available: {torch.cuda.is_available()}")
print(f"✓ GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NO GPU'}")
print(f"✓ GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
# Out:
# ✓ Current directory: C:\Users\User\Desktop\mnist\experiments\MedMNIST3D
# ✓ CUDA Available: True
# ✓ GPU: NVIDIA GeForce RTX 4060
# ✓ GPU Memory: 8.59 GB

# %%
# Train Run 1
# !python train_and_eval_pytorch.py \
    --data_flag fracturemnist3d \
    --output_root ./output/fracturemnist3d_run1_e30 \
    --num_epochs 50 \
    --batch_size 8 \
    --download \
    --model_flag resnet50 \
    --run run1

print("\n" + "="*80)
print("✓ RUN 1 COMPLETE")
print("="*80)
# Out:
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# ==> Building and training model...
# cur_best_auc: 0.7090391356684839
# cur_best_epoch 0
# cur_best_auc: 0.7344587032911702
# cur_best_epoch 16
# fracturemnist3d
# train  auc: 0.85974  acc: 0.65920
# val  auc: 0.73446  acc: 0.56311
# test  auc: 0.76084  acc: 0.55417
#
#
#
# ...
# ✓ RUN 1 COMPLETE
# ...
# 100%|##########| 50/50 [1:03:26<00:00, 76.13s/it]

# %%
# Train Run 1
# !python train_and_eval_pytorch.py \
    --data_flag fracturemnist3d \
    --output_root ./output/fracturemnist3d_run2_e30 \
    --num_epochs 30 \
    --batch_size 8 \
    --download \
    --model_flag resnet50 \
    --run run2

print("\n" + "="*80)
print("✓ RUN 1 COMPLETE")
print("="*80)
# Out:
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# ==> Building and training model...
# cur_best_auc: 0.6137803608715244
# cur_best_epoch 0
# cur_best_auc: 0.6585050635830324
# cur_best_epoch 1
# cur_best_auc: 0.6926653677153477
# cur_best_epoch 3
# cur_best_auc: 0.7022233434668461
# cur_best_epoch 6
# cur_best_auc: 0.7385340572765603
# cur_best_epoch 11
# fracturemnist3d
# train  auc: 0.78970  acc: 0.57546
# val  auc: 0.73853  acc: 0.51456
# test  auc: 0.76977  acc: 0.55833
#
#
#
# ...
# ✓ RUN 1 COMPLETE
# ...

# %%
# !python train_and_eval_pytorch.py \
    --data_flag fracturemnist3d \
    --output_root ./output/fracturemnist3d_run3_e100 \
    --num_epochs 100 \
    --batch_size 16 \
    --lr 0.0005 \
    --model_flag resnet101 \
    --dropout 0.3 \
    --download \
    --run run3
# Out:
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# usage: train_and_eval_pytorch.py [-h] [--data_flag DATA_FLAG]
#                                  [--output_root OUTPUT_ROOT]
#                                  [--num_epochs NUM_EPOCHS] [--size SIZE]
#                                  [--gpu_ids GPU_IDS] [--batch_size BATCH_SIZE]
#                                  [--conv CONV] [--pretrained_3d PRETRAINED_3D]
#                                  [--download] [--as_rgb] [--shape_transform]
#                                  [--model_path MODEL_PATH]
#                                  [--model_flag MODEL_FLAG] [--run RUN]
# train_and_eval_pytorch.py: error: unrecognized arguments: --lr 0.0005 --dropout 0.3

# %%
# !python train_and_eval_pytorch.py \
    --data_flag fracturemnist3d \
    --output_root ./output/fracturemnist3d_high_perf \
    --num_epochs 50 \
    --size 28 \
    --gpu_ids 0 \
    --batch_size 16 \
    --conv ACSConv \
    --pretrained_3d i3d \
    --download \
    --as_rgb \
    --model_flag resnet50 \
    --run best_run
# Out:
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# ==> Building and training model...
# cur_best_auc: 0.6690034039294336
# cur_best_epoch 0
# cur_best_auc: 0.6691322941722783
# cur_best_epoch 3
# cur_best_auc: 0.6994708465820021
# cur_best_epoch 4
# cur_best_auc: 0.7017536371694709
# cur_best_epoch 6
# cur_best_auc: 0.7227483080841738
# cur_best_epoch 10
# cur_best_auc: 0.7287502988222702
# cur_best_epoch 12
# fracturemnist3d
# train  auc: 0.79926  acc: 0.62220
# val  auc: 0.72875  acc: 0.48544
# ...

# %%
# Train Run 4
# !python train_and_eval_pytorch.py \
    --data_flag fracturemnist3d \
    --output_root ./output/fracturemnist3d_run4_e30 \
    --num_epochs 30 \
    --batch_size 8 \
    --download \
    --model_flag resnet50 \
    --run run4

print("\n" + "="*80)
print("✓ RUN 1 COMPLETE")
print("="*80)
# Out:
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# ==> Building and training model...
# cur_best_auc: 0.6637381026425409
# cur_best_epoch 0
# cur_best_auc: 0.6920606360630351
# cur_best_epoch 2
# cur_best_auc: 0.7038923584005552
# cur_best_epoch 9
# fracturemnist3d
# train  auc: 0.73792  acc: 0.55209
# val  auc: 0.70389  acc: 0.49515
# test  auc: 0.70575  acc: 0.47500
#
#
#
# ...
# ✓ RUN 1 COMPLETE
# ...
# 100%|##########| 30/30 [31:52<00:00, 63.76s/it]

# %%
# !python train_and_eval_pytorch.py \
    --data_flag fracturemnist3d \
    --output_root ./output/fracturemnist3d_high_perf \
    --num_epochs 50 \
    --size 28 \
    --gpu_ids 0 \
    --batch_size 16 \
    --conv ACSConv \
    --pretrained_3d i3d \
    --download \
    --as_rgb \
    --model_flag resnet50 \
    

print("\n" + "="*80)
print("✓ RUN 5 COMPLETE")
print("="*80)
# Out:
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# ==> Building and training model...
# cur_best_auc: 0.5836466471612414
# cur_best_epoch 0
# cur_best_auc: 0.6607663812781766
# cur_best_epoch 1
# cur_best_auc: 0.6741901652037597
# cur_best_epoch 2
# cur_best_auc: 0.6770738794429318
# cur_best_epoch 4
# cur_best_auc: 0.7487319357971097
# cur_best_epoch 5
# cur_best_auc: 0.7671418734093663
# cur_best_epoch 6
# fracturemnist3d
# train  auc: 0.74431  acc: 0.54138
# val  auc: 0.76714  acc: 0.53398
# ...
