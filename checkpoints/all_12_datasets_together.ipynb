# %%
# ============================================================================
# SETUP - FIXED with acsconv
# ============================================================================

import torch
print(f"✓ GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")

# Clone repository
# !git clone https://github.com/MedMNIST/experiments.git
# %cd experiments

# Install ALL required dependencies (including acsconv for 3D models)
# !pip install -q medmnist tqdm
# !pip install -q acsconv

print("\n✓ Setup Complete with acsconv!")
# Out:
# ✓ GPU: Tesla T4
# Cloning into 'experiments'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 89 (delta 15), reused 11 (delta 11), pack-reused 67 (from 1)
# Receiving objects: 100% (89/89), 36.99 KiB | 9.25 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/experiments
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.8 MB/s eta 0:00:00
#   Building wheel for acsconv (setup.py) ... done
#
# ✓ Setup Complete with acsconv!

# %%
# !pip install -q git+https://github.com/M3DV/ACSConv.git
# Out:
#   Preparing metadata (setup.py) ... done

# %%
import subprocess
import os
import torch
import gc
from datetime import datetime

# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    gc.collect()

# Change to MedMNIST2D directory
os.chdir('/content/experiments/MedMNIST2D')


datasets = [
    ('breastmnist', True),
    ('retinamnist', True),
    ('pneumoniamnist', True),
    ('bloodmnist', True),
    ('organamnist', True),
    ('dermamnist', True),
    ('organcmnist', True),
    ('organsmnist', True),
    ('octmnist', True),
    ('chestmnist', True),
    ('pathmnist', True),
    ('tissuemnist', True)
]

print("="*70)
print("Training 12 Datasets")
print("TEST RUN: 2 epoch only")
print("="*70)

for i, (dataset, needs_rgb) in enumerate(datasets, 1):
    # Clear GPU memory
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        gc.collect()

    print(f"\n[{i}/2] Training {dataset.upper()}...")

    cmd = f"""python train_and_eval_pytorch.py \
--data_flag {dataset} \
--output_root ./output_{dataset}_test \
--num_epochs 2 \
--batch_size 128 \
--model_flag resnet50 \
--resize \
--as_rgb \
--download \
--run test"""

    # Clean up command
    cmd = ' '.join(cmd.split())

    print(f"Command: {cmd}\n")

    # Run training with output capture
    result = subprocess.run(cmd, shell=True, capture_output=True, text=True)

    # Show last 50 lines of output
    output_lines = result.stdout.split('\n')
    print('\n'.join(output_lines[-50:]))

    if result.returncode == 0:
        print(f"\n✓ {dataset} completed successfully!")
    else:
        print(f"\n✗ {dataset} FAILED with error code {result.returncode}")
        if result.stderr:
            print("ERROR OUTPUT (last 30 lines):")
            error_lines = result.stderr.split('\n')
            print('\n'.join(error_lines[-30:]))

    # Clear memory after each dataset
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect()

print("\n" + "="*70)
print("TEST COMPLETE!")
print("="*70)
# Out:
# ======================================================================
# Training 12 Datasets
# TEST RUN: 2 epoch only
# ======================================================================
#
# [1/2] Training BREASTMNIST...
# Command: python train_and_eval_pytorch.py --data_flag breastmnist --output_root ./output_breastmnist_test --num_epochs 2 --batch_size 128 --model_flag resnet50 --resize --as_rgb --download --run test
#
# ==> Preparing data...
# ==> Building and training model...
# cur_best_auc: 0.5497076023391813
# cur_best_epoch 0
# breastmnist
# train  auc: 0.61431  acc: 0.73077
# val  auc: 0.54971  acc: 0.73077
# test  auc: 0.59252  acc: 0.73077
#
#
#
# ✓ breastmnist completed successfully!
#
# [2/2] Training RETINAMNIST...
# Command: python train_and_eval_pytorch.py --data_flag retinamnist --output_root ./output_retinamnist_test --num_epochs 2 --batch_size 128 --model_flag resnet50 --resize --as_rgb --download --run test
#
# ==> Preparing data...
# ==> Building and training model...
# cur_best_auc: 0.5321287317620651
# cur_best_epoch 0
# cur_best_auc: 0.650456762239371
# cur_best_epoch 1
# retinamnist
# train  auc: 0.59724  acc: 0.17963
# val  auc: 0.65046  acc: 0.16667
# test  auc: 0.63327  acc: 0.17000
#
#
#
# ✓ retinamnist completed successfully!
#
# [3/2] Training PNEUMONIAMNIST...
# Command: python train_and_eval_pytorch.py --data_flag pneumoniamnist --output_root ./output_pneumoniamnist_test --num_epochs 2 --batch_size 128 --model_flag resnet50 --resize --as_rgb --download --run test
#
# ==> Preparing data...
# ==> Building and training model...
# cur_best_auc: 0.7969627725411788
# cur_best_epoch 0
# cur_best_auc: 0.9872703037227458
# cur_best_epoch 1
# pneumoniamnist
# train  auc: 0.99265  acc: 0.95370
# val  auc: 0.98727  acc: 0.94466
# test  auc: 0.95562  acc: 0.79327
#
#
#
# ✓ pneumoniamnist completed successfully!
#
# [4/2] Training BLOODMNIST...
# Command: python train_and_eval_pytorch.py --data_flag bloodmnist --output_root ./output_bloodmnist_test --num_epochs 2 --batch_size 128 --model_flag resnet50 --resize --as_rgb --download --run test
#
# ==> Preparing data...
# ==> Building and training model...
# cur_best_auc: 0.9699224866466981
# cur_best_epoch 0
# cur_best_auc: 0.9928444158945292
# cur_best_epoch 1
# bloodmnist
# train  auc: 0.99309  acc: 0.91747
# val  auc: 0.99284  acc: 0.90479
# test  auc: 0.99156  acc: 0.90763
#
#
#
# ✓ bloodmnist completed successfully!
#
# [5/2] Training ORGANAMNIST...
# Command: python train_and_eval_pytorch.py --data_flag organamnist --output_root ./output_organamnist_test --num_epochs 2 --batch_size 128 --model_flag resnet50 --resize --as_rgb --download --run test
#
# ==> Preparing data...
# ==> Building and training model...
# cur_best_auc: 0.9953077293615991
# cur_best_epoch 0
# cur_best_auc: 0.9998239832172741
# cur_best_epoch 1
# organamnist
# train  auc: 0.99980  acc: 0.98559
# val  auc: 0.99982  acc: 0.98090
# test  auc: 0.99680  acc: 0.92609
#
#
#
# ✓ organamnist completed successfully!
#
# [6/2] Training DERMAMNIST...
# Command: python train_and_eval_pytorch.py --data_flag dermamnist --output_root ./output_dermamnist_test --num_epochs 2 --batch_size 128 --model_flag resnet50 --resize --as_rgb --download --run test
#
# ==> Preparing data...
# ==> Building and training model...
# cur_best_auc: 0.824618133912165
# cur_best_epoch 0
# cur_best_auc: 0.8695852682052738
# cur_best_epoch 1
# dermamnist
# train  auc: 0.85943  acc: 0.69316
# val  auc: 0.86959  acc: 0.69192
# test  auc: 0.84536  acc: 0.68030
#
#
#
# ✓ dermamnist completed successfully!
#
# [7/2] Training ORGANCMNIST...
# Command: python train_and_eval_pytorch.py --data_flag organcmnist --output_root ./output_organcmnist_test --num_epochs 2 --batch_size 128 --model_flag resnet50 --resize --as_rgb --download --run test
#
# ==> Preparing data...
# ==> Building and training model...
# cur_best_auc: 0.9567986910424195
# cur_best_epoch 0
# cur_best_auc: 0.9981222656203994
# cur_best_epoch 1
# organcmnist
# train  auc: 0.99670  acc: 0.93426
# val  auc: 0.99812  acc: 0.94941
# test  auc: 0.98518  acc: 0.85772
#
#
#
# ✓ organcmnist completed successfully!
#
# [8/2] Training ORGANSMNIST...
# Command: python train_and_eval_pytorch.py --data_flag organsmnist --output_root ./output_organsmnist_test --num_epochs 2 --batch_size 128 --model_flag resnet50 --resize --as_rgb --download --run test
#
# ==> Preparing data...
# ==> Building and training model...
# cur_best_auc: 0.8265260089278104
# cur_best_epoch 0
# cur_best_auc: 0.9889237200101543
# cur_best_epoch 1
# organsmnist
# train  auc: 0.98386  acc: 0.80807
# val  auc: 0.98892  acc: 0.83931
# test  auc: 0.96825  acc: 0.72641
#
#
#
# ✓ organsmnist completed successfully!
#
# [9/2] Training OCTMNIST...
# Command: python train_and_eval_pytorch.py --data_flag octmnist --output_root ./output_octmnist_test --num_epochs 2 --batch_size 128 --model_flag resnet50 --resize --as_rgb --download --run test
#
# ==> Preparing data...
# ==> Building and training model...
# cur_best_auc: 0.9323962990313599
# cur_best_epoch 0
# cur_best_auc: 0.9672247882185627
# cur_best_epoch 1
# octmnist
# train  auc: 0.97063  acc: 0.90662
# val  auc: 0.96722  acc: 0.90113
# test  auc: 0.96045  acc: 0.74400
#
#
#
# ✓ octmnist completed successfully!
#
# [10/2] Training CHESTMNIST...
# Command: python train_and_eval_pytorch.py --data_flag chestmnist --output_root ./output_chestmnist_test --num_epochs 2 --batch_size 128 --model_flag resnet50 --resize --as_rgb --download --run test
#
# ==> Preparing data...
# ==> Building and training model...
# cur_best_auc: 0.6381846402115635
# cur_best_epoch 0
# cur_best_auc: 0.7245378328267471
# cur_best_epoch 1
# chestmnist
# train  auc: 0.73335  acc: 0.94865
# val  auc: 0.72454  acc: 0.94907
# test  auc: 0.72410  acc: 0.94744
#
#
#
# ✓ chestmnist completed successfully!
#
# [11/2] Training PATHMNIST...
# Command: python train_and_eval_pytorch.py --data_flag pathmnist --output_root ./output_pathmnist_test --num_epochs 2 --batch_size 128 --model_flag resnet50 --resize --as_rgb --download --run test
