# %%
# !pip install medmnist
# !pip install torch torchvision
# !pip install tensorboardX
# !pip install tqdm
# !pip install git+https://github.com/M3DV/ACSConv.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.9 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/M3DV/ACSConv.git to /tmp/pip-req-build-cw3j7t5p
#   Running command git clone --filter=blob:none --quiet https://github.com/M3DV/ACSConv.git /tmp/pip-req-build-cw3j7t5p
#   Resolved https://github.com/M3DV/ACSConv.git to commit d1d60c83f4503c5a83aeecf7f816983351a7fa7f
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ACSConv: filename=ACSConv-0.1.1-py3-none-any.whl size=26976 sha256=710be4acf021bd937450f36a85fda7906f196d7b0ca00c9725e1e687357b1804
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wdr6c1ug/wheels/9b/f1/c9/cd0ddaa32d58a56e954d28b4684812a3c262213ddc4a85dc94
# Successfully built ACSConv
# ...

# %%
# !git clone https://github.com/MedMNIST/experiments.git
# Out:
# Cloning into 'experiments'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 89 (delta 15), reused 11 (delta 11), pack-reused 67 (from 1)
# Receiving objects: 100% (89/89), 36.99 KiB | 2.85 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# %cd experiments/MedMNIST3D
# Out:
# /content/experiments/MedMNIST3D

# %%
# %cd /content/experiments/MedMNIST3D

# !python train_and_eval_pytorch.py \
    --data_flag adrenalmnist3d \
    --output_root ./output/adrenalmnist3d_run1_e100 \
    --num_epochs 10 \
    --batch_size 32 \
    --download \
    --model_flag resnet50 \
    --run run1
# Out:
# /content/experiments/MedMNIST3D
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.8355263157894737
# cur_best_epoch 0
#  40% 4/10 [07:11<10:48, 108.02s/it]cur_best_auc: 0.8696172248803827
# cur_best_epoch 4
# 100% 10/10 [18:01<00:00, 108.13s/it]
# adrenalmnist3d
# train  auc: 0.84642  acc: 0.73148
# val  auc: 0.86962  acc: 0.71429
# test  auc: 0.85792  acc: 0.72819

# %%
# %cd /content/experiments/MedMNIST3D

# !python train_and_eval_pytorch.py \
    --data_flag adrenalmnist3d \
    --output_root ./output/adrenalmnist3d_run2\
    --num_epochs 10 \
    --batch_size 32 \
    --download \
    --model_flag resnet50 \
    --run run2
# Out:
# /content/experiments/MedMNIST3D
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# 100% 277k/277k [00:00<00:00, 445kB/s]
# ==> Building and training model...
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.5950956937799042
# cur_best_epoch 0
#  10% 1/10 [01:48<16:16, 108.53s/it]cur_best_auc: 0.833732057416268
# cur_best_epoch 1
#  40% 4/10 [07:12<10:48, 108.08s/it]cur_best_auc: 0.8522727272727272
# cur_best_epoch 4
#  50% 5/10 [09:00<09:00, 108.07s/it]cur_best_auc: 0.8654306220095693
# cur_best_epoch 5
#  70% 7/10 [12:37<05:24, 108.12s/it]cur_best_auc: 0.8779904306220097
# cur_best_epoch 7
#  80% 8/10 [14:25<03:36, 108.15s/it]cur_best_auc: 0.8857655502392344
# cur_best_epoch 8
# 100% 10/10 [18:01<00:00, 108.16s/it]
# adrenalmnist3d
# train  auc: 0.94912  acc: 0.89141
# val  auc: 0.88577  acc: 0.85714
# test  auc: 0.84374  acc: 0.81208

# %%
# %cd /content/experiments/MedMNIST3D

# !python train_and_eval_pytorch.py \
    --data_flag adrenalmnist3d \
    --output_root ./output/adrenalmnist3d_run3 \
    --num_epochs 10 \
    --batch_size 32 \
    --download \
    --model_flag resnet50 \
    --run run3
# Out:
# /content/experiments/MedMNIST3D
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.8307416267942582
# cur_best_epoch 0
#  30% 3/10 [05:24<12:36, 108.11s/it]cur_best_auc: 0.8415071770334928
# cur_best_epoch 3
#  40% 4/10 [07:12<10:48, 108.12s/it]cur_best_auc: 0.8433014354066984
# cur_best_epoch 4
#  50% 5/10 [09:00<09:00, 108.13s/it]cur_best_auc: 0.8480861244019139
# cur_best_epoch 5
# 100% 10/10 [18:01<00:00, 108.17s/it]
# adrenalmnist3d
# train  auc: 0.86795  acc: 0.85185
# val  auc: 0.84809  acc: 0.86735
# test  auc: 0.86672  acc: 0.78523

# %%
# %cd /content/experiments/MedMNIST3D

# !python train_and_eval_pytorch.py \
    --data_flag adrenalmnist3d \
    --output_root ./output/adrenalmnist3d_run4 \
    --num_epochs 10 \
    --batch_size 32 \
    --download \
    --model_flag resnet50 \
    --run run4
# Out:
# /content/experiments/MedMNIST3D
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.8169856459330144
# cur_best_epoch 0
#  10% 1/10 [01:48<16:17, 108.64s/it]cur_best_auc: 0.8199760765550239
# cur_best_epoch 1
#  20% 2/10 [03:36<14:26, 108.28s/it]cur_best_auc: 0.8295454545454546
# cur_best_epoch 2
#  50% 5/10 [09:00<08:59, 107.99s/it]cur_best_auc: 0.8444976076555024
# cur_best_epoch 5
# 100% 10/10 [18:00<00:00, 108.03s/it]
# adrenalmnist3d
# train  auc: 0.88529  acc: 0.87205
# val  auc: 0.84450  acc: 0.84694
# test  auc: 0.85634  acc: 0.81544

# %%
# %cd /content/experiments/MedMNIST3D

# !python train_and_eval_pytorch.py \
    --data_flag adrenalmnist3d \
    --output_root ./output/adrenalmnist3d_run5 \
    --num_epochs 10 \
    --batch_size 32 \
    --download \
    --model_flag resnet50 \
    --run run5
# Out:
# /content/experiments/MedMNIST3D
# The ``converters`` are currently experimental. It may not support operations including (but not limited to) Functions in ``torch.nn.functional`` that involved data dimension
# ==> Preparing data...
# ==> Building and training model...
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.8480861244019139
# cur_best_epoch 0
#  50% 5/10 [09:00<09:00, 108.02s/it]cur_best_auc: 0.8528708133971292
# cur_best_epoch 5
#  60% 6/10 [10:48<07:12, 108.04s/it]cur_best_auc: 0.8576555023923446
# cur_best_epoch 6
# 100% 10/10 [18:00<00:00, 108.08s/it]
# adrenalmnist3d
# train  auc: 0.88290  acc: 0.86616
# val  auc: 0.85766  acc: 0.85714
# test  auc: 0.87450  acc: 0.81879
