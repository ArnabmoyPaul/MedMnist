# %%
# !pip install -q medmnist pillow scipy tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import transforms, models
from medmnist import INFO
import numpy as np
from sklearn.metrics import roc_auc_score
import time
import os
import warnings
warnings.filterwarnings('ignore')

print("="*80)
print("🚀 PRODUCTION: ALL 18 MEDMNIST DATASETS (2D+2.5D ResNet-50)")
print("="*80)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")

benchmarks = {
    # 2D Datasets
    'pathmnist': 0.989, 'chestmnist': 0.773, 'dermamnist': 0.920, 'octmnist': 0.958,
    'pneumoniamnist': 0.962, 'retinamnist': 0.716, 'breastmnist': 0.866, 'bloodmnist': 0.998,
    'tissuemnist': 0.932, 'organamnist': 0.998, 'organcmnist': 0.993, 'organsmnist': 0.975,
    # 3D Datasets
    'adversarialmnist3d': 0.892, 'nodulemnist3d': 0.913, 'synapsemnist3d': 0.975,
    'fracturemnist3d': 0.871, 'spleenmnist3d': 0.973, 'abasemnist3d': 0.889
}

all_results = {}

def is_3d(ds_name):
    return ds_name.endswith('3d')

def is_multilabel(ds_name):
    """ChestMNIST is multi-label (14 diseases)"""
    return ds_name == 'chestmnist'

def safe_target_processing(target, multilabel=False):
    if multilabel:
        # Multi-label: keep as float, shape (B, num_classes)
        return target.float()
    else:
        # Single-label: squeeze to (B,)
        if target.ndim > 1:
            target = target.squeeze(-1)
        if target.ndim == 0:
            target = target.unsqueeze(0)
        return target.long()

def get_2d_transform():
    return transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

def get_3d_transform_2_5d():
    def preprocess_3d_to_2_5d(volume):
        if volume.ndim == 4 and volume.shape[0] == 1:
            volume = volume[0]
        if volume.ndim != 3:
            volume = volume.squeeze()
        D, H, W = volume.shape
        idx1, idx2, idx3 = int(D*0.25), int(D*0.50), int(D*0.75)
        slice1 = volume[idx1].astype(np.float32) / 255.0
        slice2 = volume[idx2].astype(np.float32) / 255.0
        slice3 = volume[idx3].astype(np.float32) / 255.0
        from scipy.ndimage import zoom
        zoom_factors = (224/H, 224/W)
        slice1 = zoom(slice1, zoom_factors, order=1)
        slice2 = zoom(slice2, zoom_factors, order=1)
        slice3 = zoom(slice3, zoom_factors, order=1)
        rgb_img = np.stack([slice1, slice2, slice3], axis=0)
        return torch.tensor(rgb_img, dtype=torch.float32)
    return transforms.Compose([
        transforms.Lambda(preprocess_3d_to_2_5d),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

def get_resnet50(num_classes):
    model = models.resnet50(weights='IMAGENET1K_V2')
    model.fc = nn.Linear(2048, num_classes)
    return model

def train_single_dataset(ds_name, epochs=5):
    print(f"\n{'='*70}")
    print(f"🔬 ResNet-50 {'2.5D' if is_3d(ds_name) else '2D'}: {ds_name}")
    print(f"{'='*70}")

    try:
        info = INFO[ds_name]
        num_classes = len(info['label'])
        multilabel = is_multilabel(ds_name)
        if multilabel:
            print(f"⚠️  Multi-label dataset: {num_classes} classes")
    except:
        print(f"❌ NOT FOUND: {ds_name}")
        return 0.5

    transform = get_3d_transform_2_5d() if is_3d(ds_name) else get_2d_transform()
    as_rgb = not is_3d(ds_name)

    try:
        module = __import__('medmnist', fromlist=[info['python_class']])
        DataClass = getattr(module, info['python_class'])
        train_ds = DataClass(split='train', transform=transform, download=True, as_rgb=as_rgb)
        val_ds = DataClass(split='val', transform=transform, download=True, as_rgb=as_rgb)
        test_ds = DataClass(split='test', transform=transform, download=True, as_rgb=as_rgb)
        print(f"✅ Train: {len(train_ds):,} | Val: {len(val_ds):,} | Test: {len(test_ds):,}")
    except Exception as e:
        print(f"❌ Load error: {e}")
        return 0.5

    batch = 64
    train_loader = DataLoader(train_ds, batch_size=batch, shuffle=True, num_workers=2, pin_memory=True)
    val_loader = DataLoader(val_ds, batch_size=batch, shuffle=False, num_workers=2, pin_memory=True)
    test_loader = DataLoader(test_ds, batch_size=batch, shuffle=False, num_workers=2, pin_memory=True)

    model = get_resnet50(num_classes)
    model = model.to(device)
    print(f"✅ Model: {sum(p.numel() for p in model.parameters()):,} params")

    for param in list(model.parameters())[:-60]:
        param.requires_grad = False

    trainable = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.AdamW(trainable, lr=1e-3, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    best_auc = 0
    best_state = None
    start_time = time.time()

    for epoch in range(epochs):
        model.train()
        train_loss = 0

        for data, target in train_loader:
            data, target = data.to(device), target.to(device)
            target = safe_target_processing(target, multilabel)

            min_b = min(data.size(0), target.size(0))
            data, target = data[:min_b], target[:min_b]

            optimizer.zero_grad()
            output = model(data)

            # Different loss for multi-label vs single-label
            if multilabel:
                loss = F.binary_cross_entropy_with_logits(output, target)
            else:
                loss = F.cross_entropy(output, target)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            train_loss += loss.item()

        scheduler.step()

        # Validation
        model.eval()
        val_preds, val_targets = [], []
        with torch.no_grad():
            for data, target in val_loader:
                data, target = data.to(device), target.to(device)
                target = safe_target_processing(target, multilabel)

                min_b = min(data.size(0), target.size(0))
                data, target = data[:min_b], target[:min_b]

                # Different prediction for multi-label vs single-label
                if multilabel:
                    prob = torch.sigmoid(model(data))
                else:
                    prob = F.softmax(model(data), dim=1)

                val_preds.extend(prob.cpu().numpy())
                val_targets.extend(target.cpu().numpy())

        val_preds = np.array(val_preds)
        val_targets = np.array(val_targets)

        try:
            if multilabel:
                val_auc = roc_auc_score(val_targets, val_preds, average='macro')
            elif num_classes > 2:
                val_auc = roc_auc_score(val_targets, val_preds, multi_class='ovr')
            else:
                val_auc = roc_auc_score(val_targets, val_preds[:, 1])
        except:
            val_auc = 0.5

        if val_auc > best_auc:
            best_auc = val_auc
            best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}

        elapsed = time.time() - start_time
        print(f"  Epoch {epoch+1}: Loss={train_loss/len(train_loader):.3f} | AUC={val_auc:.4f} | Best={best_auc:.4f} | {elapsed/60:.1f}m")

    # Test
    if best_state:
        model.load_state_dict(best_state)
    model.eval()

    test_preds, test_targets = [], []
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            target = safe_target_processing(target, multilabel)

            min_b = min(data.size(0), target.size(0))
            data, target = data[:min_b], target[:min_b]

            if multilabel:
                prob = torch.sigmoid(model(data))
            else:
                prob = F.softmax(model(data), dim=1)

            test_preds.extend(prob.cpu().numpy())
            test_targets.extend(target.cpu().numpy())

    test_preds = np.array(test_preds)
    test_targets = np.array(test_targets)

    try:
        if multilabel:
            test_auc = roc_auc_score(test_targets, test_preds, average='macro')
        elif num_classes > 2:
            test_auc = roc_auc_score(test_targets, test_preds, multi_class='ovr')
        else:
            test_auc = roc_auc_score(test_targets, test_preds[:, 1])
    except:
        test_auc = 0.5

    total_time = time.time() - start_time
    bench = benchmarks.get(ds_name, 0)
    gap = test_auc - bench

    print(f"✅ {ds_name} | AUC: {test_auc:.4f} | Bench: {bench:.3f} | Gap: {gap:+.4f}")
    all_results[ds_name] = test_auc
    return test_auc

# ALL 18 DATASETS
all_datasets = [
    # 2D
    'pathmnist','chestmnist','dermamnist','octmnist','pneumoniamnist','retinamnist',
    'breastmnist','bloodmnist','tissuemnist','organamnist','organcmnist','organsmnist',
    # 3D
    'adversarialmnist3d','nodulemnist3d','synapsemnist3d','fracturemnist3d','spleenmnist3d','abasemnist3d'
]

print("\n🚀 FULL 2D AND 2.5D (MULTI-LABEL FIXED)")

for ds in all_datasets:
    if os.path.exists(f'{ds}_best.pth'):
        os.remove(f'{ds}_best.pth')

for ds_name in all_datasets:
    try:
        train_single_dataset(ds_name, epochs=5)
        torch.cuda.empty_cache()
    except Exception as e:
        print(f"❌ {ds_name} FAILED: {str(e)[:100]}")
        all_results[ds_name] = 0.5

print("\n" + "="*80)
print("🎯 FINAL RESULTS")
print("="*80)
print(f"{'Dataset':<20} {'AUC':<10} {'Benchmark':<10} {'Gap':<10}")
print("-"*60)
for ds in all_datasets:
    bench = benchmarks.get(ds, 0)
    auc = all_results.get(ds, 0.5)
    gap = auc - bench
    status = "✅" if gap > -0.1 else "🔴"
    print(f"{ds:<20} {auc:<10.4f} {bench:<10.3f} {gap:+10.4f} {status}")

avg_auc = np.mean(list(all_results.values()))
print("="*80)
print(f"📈 Average AUC: {avg_auc:.4f}")
print("="*80)
# Out:
# ================================================================================
# 🚀 PRODUCTION: ALL 18 MEDMNIST DATASETS (2D+2.5D ResNet-50)
# ================================================================================
# Device: cuda
#
# 🚀 FULL 2D AND 2.5D (MULTI-LABEL FIXED)
#
# ======================================================================
# 🔬 ResNet-50 2D: pathmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\pathmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pathmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pathmnist.npz
# ✅ Train: 89,996 | Val: 10,004 | Test: 7,180
# ✅ Model: 23,526,473 params
#   Epoch 1: Loss=0.155 | AUC=0.9995 | Best=0.9995 | 4.9m
#   Epoch 2: Loss=0.055 | AUC=0.9988 | Best=0.9995 | 9.8m
#   Epoch 3: Loss=0.024 | AUC=0.9980 | Best=0.9995 | 14.6m
#   Epoch 4: Loss=0.010 | AUC=0.9998 | Best=0.9998 | 19.5m
#   Epoch 5: Loss=0.004 | AUC=0.9999 | Best=0.9999 | 24.3m
# ✅ pathmnist | AUC: 0.9954 | Bench: 0.989 | Gap: +0.0064
#
# ======================================================================
# 🔬 ResNet-50 2D: chestmnist
# ======================================================================
# ⚠️  Multi-label dataset: 14 classes
# Using downloaded and verified file: C:\Users\User\.medmnist\chestmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\chestmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\chestmnist.npz
# ✅ Train: 78,468 | Val: 11,219 | Test: 22,433
# ✅ Model: 23,536,718 params
#   Epoch 1: Loss=0.168 | AUC=0.7601 | Best=0.7601 | 4.3m
#   Epoch 2: Loss=0.158 | AUC=0.7643 | Best=0.7643 | 8.7m
#   Epoch 3: Loss=0.144 | AUC=0.7631 | Best=0.7643 | 13.0m
#   Epoch 4: Loss=0.108 | AUC=0.7328 | Best=0.7643 | 17.4m
#   Epoch 5: Loss=0.055 | AUC=0.7082 | Best=0.7643 | 21.7m
# ✅ chestmnist | AUC: 0.7608 | Bench: 0.773 | Gap: -0.0122
#
# ======================================================================
# 🔬 ResNet-50 2D: dermamnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\dermamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\dermamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\dermamnist.npz
# ✅ Train: 7,007 | Val: 1,003 | Test: 2,005
# ✅ Model: 23,522,375 params
#   Epoch 1: Loss=0.798 | AUC=0.9284 | Best=0.9284 | 0.6m
#   Epoch 2: Loss=0.564 | AUC=0.9253 | Best=0.9284 | 1.2m
#   Epoch 3: Loss=0.321 | AUC=0.9359 | Best=0.9359 | 1.8m
#   Epoch 4: Loss=0.088 | AUC=0.9274 | Best=0.9359 | 2.5m
#   Epoch 5: Loss=0.017 | AUC=0.9331 | Best=0.9359 | 3.1m
# ✅ dermamnist | AUC: 0.9230 | Bench: 0.920 | Gap: +0.0030
#
# ======================================================================
# 🔬 ResNet-50 2D: octmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\octmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\octmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\octmnist.npz
# ✅ Train: 97,477 | Val: 10,832 | Test: 1,000
# ✅ Model: 23,516,228 params
#   Epoch 1: Loss=0.358 | AUC=0.9654 | Best=0.9654 | 5.2m
#   Epoch 2: Loss=0.252 | AUC=0.9718 | Best=0.9718 | 10.5m
#   Epoch 3: Loss=0.174 | AUC=0.9728 | Best=0.9728 | 15.7m
#   Epoch 4: Loss=0.081 | AUC=0.9740 | Best=0.9740 | 20.9m
#   Epoch 5: Loss=0.027 | AUC=0.9754 | Best=0.9754 | 26.1m
# ✅ octmnist | AUC: 0.9564 | Bench: 0.958 | Gap: -0.0016
#
# ======================================================================
# 🔬 ResNet-50 2D: pneumoniamnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\pneumoniamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pneumoniamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pneumoniamnist.npz
# ✅ Train: 4,708 | Val: 524 | Test: 624
# ✅ Model: 23,512,130 params
#   Epoch 1: Loss=0.156 | AUC=0.9912 | Best=0.9912 | 0.5m
#   Epoch 2: Loss=0.051 | AUC=0.9945 | Best=0.9945 | 1.0m
#   Epoch 3: Loss=0.020 | AUC=0.9922 | Best=0.9945 | 1.5m
#   Epoch 4: Loss=0.009 | AUC=0.9959 | Best=0.9959 | 2.0m
#   Epoch 5: Loss=0.001 | AUC=0.9959 | Best=0.9959 | 2.4m
# ✅ pneumoniamnist | AUC: 0.9719 | Bench: 0.962 | Gap: +0.0099
#
# ======================================================================
# 🔬 ResNet-50 2D: retinamnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\retinamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\retinamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\retinamnist.npz
# ✅ Train: 1,080 | Val: 120 | Test: 400
# ✅ Model: 23,518,277 params
#   Epoch 1: Loss=1.271 | AUC=0.7574 | Best=0.7574 | 0.3m
#   Epoch 2: Loss=0.960 | AUC=0.8001 | Best=0.8001 | 0.6m
#   Epoch 3: Loss=0.444 | AUC=0.7375 | Best=0.8001 | 0.9m
#   Epoch 4: Loss=0.112 | AUC=0.7280 | Best=0.8001 | 1.2m
#   Epoch 5: Loss=0.024 | AUC=0.7522 | Best=0.8001 | 1.5m
# ✅ retinamnist | AUC: 0.7335 | Bench: 0.716 | Gap: +0.0175
#
# ======================================================================
# 🔬 ResNet-50 2D: breastmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\breastmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\breastmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\breastmnist.npz
# ✅ Train: 546 | Val: 78 | Test: 156
# ✅ Model: 23,512,130 params
#   Epoch 1: Loss=0.507 | AUC=0.7072 | Best=0.7072 | 0.2m
#   Epoch 2: Loss=0.164 | AUC=0.7636 | Best=0.7636 | 0.5m
#   Epoch 3: Loss=0.034 | AUC=0.7619 | Best=0.7636 | 0.7m
#   Epoch 4: Loss=0.007 | AUC=0.7711 | Best=0.7711 | 0.9m
#   Epoch 5: Loss=0.002 | AUC=0.8488 | Best=0.8488 | 1.1m
# ✅ breastmnist | AUC: 0.8350 | Bench: 0.866 | Gap: -0.0310
#
# ======================================================================
# 🔬 ResNet-50 2D: bloodmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\bloodmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\bloodmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\bloodmnist.npz
# ✅ Train: 11,959 | Val: 1,712 | Test: 3,421
# ✅ Model: 23,524,424 params
#   Epoch 1: Loss=0.359 | AUC=0.9958 | Best=0.9958 | 0.9m
#   Epoch 2: Loss=0.116 | AUC=0.9972 | Best=0.9972 | 1.7m
#   Epoch 3: Loss=0.041 | AUC=0.9977 | Best=0.9977 | 2.6m
#   Epoch 4: Loss=0.009 | AUC=0.9981 | Best=0.9981 | 3.5m
#   Epoch 5: Loss=0.002 | AUC=0.9982 | Best=0.9982 | 4.4m
# ✅ bloodmnist | AUC: 0.9982 | Bench: 0.998 | Gap: +0.0002
#
# ======================================================================
# 🔬 ResNet-50 2D: tissuemnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\tissuemnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\tissuemnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\tissuemnist.npz
# ✅ Train: 165,466 | Val: 23,640 | Test: 47,280
# ✅ Model: 23,524,424 params
#   Epoch 1: Loss=1.042 | AUC=0.9173 | Best=0.9173 | 8.9m
#   Epoch 2: Loss=0.877 | AUC=0.9248 | Best=0.9248 | 17.7m
#   Epoch 3: Loss=0.717 | AUC=0.9257 | Best=0.9257 | 26.6m
#   Epoch 4: Loss=0.429 | AUC=0.9196 | Best=0.9257 | 35.4m
#   Epoch 5: Loss=0.160 | AUC=0.9104 | Best=0.9257 | 44.3m
# ✅ tissuemnist | AUC: 0.9266 | Bench: 0.932 | Gap: -0.0054
#
# ======================================================================
# 🔬 ResNet-50 2D: organamnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\organamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organamnist.npz
# ✅ Train: 34,561 | Val: 6,491 | Test: 17,778
# ✅ Model: 23,530,571 params
#   Epoch 1: Loss=0.189 | AUC=0.9997 | Best=0.9997 | 2.1m
#   Epoch 2: Loss=0.032 | AUC=0.9999 | Best=0.9999 | 4.2m
#   Epoch 3: Loss=0.011 | AUC=0.9999 | Best=0.9999 | 6.3m
#   Epoch 4: Loss=0.005 | AUC=1.0000 | Best=1.0000 | 8.4m
#   Epoch 5: Loss=0.001 | AUC=0.9999 | Best=1.0000 | 10.5m
# ✅ organamnist | AUC: 0.9985 | Bench: 0.998 | Gap: +0.0005
#
# ======================================================================
# 🔬 ResNet-50 2D: organcmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\organcmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organcmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organcmnist.npz
# ✅ Train: 12,975 | Val: 2,392 | Test: 8,216
# ✅ Model: 23,530,571 params
#   Epoch 1: Loss=0.327 | AUC=0.9995 | Best=0.9995 | 0.9m
#   Epoch 2: Loss=0.090 | AUC=0.9995 | Best=0.9995 | 1.9m
#   Epoch 3: Loss=0.034 | AUC=0.9998 | Best=0.9998 | 2.8m
#   Epoch 4: Loss=0.007 | AUC=0.9998 | Best=0.9998 | 3.8m
#   Epoch 5: Loss=0.003 | AUC=0.9998 | Best=0.9998 | 4.7m
# ✅ organcmnist | AUC: 0.9963 | Bench: 0.993 | Gap: +0.0033
#
# ======================================================================
# 🔬 ResNet-50 2D: organsmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\organsmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organsmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organsmnist.npz
# ✅ Train: 13,932 | Val: 2,452 | Test: 8,827
# ✅ Model: 23,530,571 params
#   Epoch 1: Loss=0.543 | AUC=0.9932 | Best=0.9932 | 1.0m
#   Epoch 2: Loss=0.230 | AUC=0.9936 | Best=0.9936 | 2.0m
#   Epoch 3: Loss=0.108 | AUC=0.9937 | Best=0.9937 | 3.0m
#   Epoch 4: Loss=0.054 | AUC=0.9944 | Best=0.9944 | 4.0m
#   Epoch 5: Loss=0.020 | AUC=0.9946 | Best=0.9946 | 4.9m
# ✅ organsmnist | AUC: 0.9822 | Bench: 0.975 | Gap: +0.0072
#
# ======================================================================
# 🔬 ResNet-50 2.5D: adversarialmnist3d
# ======================================================================
# ❌ NOT FOUND: adversarialmnist3d
#
# ======================================================================
# 🔬 ResNet-50 2.5D: nodulemnist3d
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\nodulemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\nodulemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\nodulemnist3d.npz
# ✅ Train: 1,158 | Val: 165 | Test: 310
# ✅ Model: 23,512,130 params
# ❌ nodulemnist3d FAILED: Can't pickle local object 'get_3d_transform_2_5d.<locals>.preprocess_3d_to_2_5d'
#
# ======================================================================
# 🔬 ResNet-50 2.5D: synapsemnist3d
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# ✅ Train: 1,230 | Val: 177 | Test: 352
# ✅ Model: 23,512,130 params
# ❌ synapsemnist3d FAILED: Can't pickle local object 'get_3d_transform_2_5d.<locals>.preprocess_3d_to_2_5d'
#
# ======================================================================
# 🔬 ResNet-50 2.5D: fracturemnist3d
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# ✅ Train: 1,027 | Val: 103 | Test: 240
# ✅ Model: 23,514,179 params
# ❌ fracturemnist3d FAILED: Can't pickle local object 'get_3d_transform_2_5d.<locals>.preprocess_3d_to_2_5d'
#
# ======================================================================
# 🔬 ResNet-50 2.5D: spleenmnist3d
# ======================================================================
# ❌ NOT FOUND: spleenmnist3d
#
# ======================================================================
# 🔬 ResNet-50 2.5D: abasemnist3d
# ======================================================================
# ❌ NOT FOUND: abasemnist3d
#
# ================================================================================
# 🎯 FINAL RESULTS
# ================================================================================
# Dataset              AUC        Benchmark  Gap
# ------------------------------------------------------------
# pathmnist            0.9954     0.989         +0.0064 ✅
# chestmnist           0.7608     0.773         -0.0122 ✅
# dermamnist           0.9230     0.920         +0.0030 ✅
# octmnist             0.9564     0.958         -0.0016 ✅
# pneumoniamnist       0.9719     0.962         +0.0099 ✅
# retinamnist          0.7335     0.716         +0.0175 ✅
# breastmnist          0.8350     0.866         -0.0310 ✅
# bloodmnist           0.9982     0.998         +0.0002 ✅
# tissuemnist          0.9266     0.932         -0.0054 ✅
# organamnist          0.9985     0.998         +0.0005 ✅
# organcmnist          0.9963     0.993         +0.0033 ✅
# organsmnist          0.9822     0.975         +0.0072 ✅
# adversarialmnist3d   0.5000     0.892         -0.3920 🔴
# nodulemnist3d        0.5000     0.913         -0.4130 🔴
# synapsemnist3d       0.5000     0.975         -0.4750 🔴
# fracturemnist3d      0.5000     0.871         -0.3710 🔴
# spleenmnist3d        0.5000     0.973         -0.4730 🔴
# abasemnist3d         0.5000     0.889         -0.3890 🔴
# ================================================================================
# 📈 Average AUC: 0.8385
# ================================================================================

# %%
# !pip install -q medmnist pillow scipy tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import transforms, models
from medmnist import INFO
import numpy as np
from sklearn.metrics import roc_auc_score
import time
import os
import warnings
warnings.filterwarnings('ignore')

print("="*80)
print("🚀 PRODUCTION: ALL 18 MEDMNIST DATASETS (2D+2.5D ResNet-50)")
print("   CONFIG: 30 Epochs | Early Stopping (Patience=5)")
print("="*80)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")

benchmarks = {
    # 2D Datasets
    'pathmnist': 0.989, 'chestmnist': 0.773, 'dermamnist': 0.920, 'octmnist': 0.958,
    'pneumoniamnist': 0.962, 'retinamnist': 0.716, 'breastmnist': 0.866, 'bloodmnist': 0.998,
    'tissuemnist': 0.932, 'organamnist': 0.998, 'organcmnist': 0.993, 'organsmnist': 0.975,
    # 3D Datasets
    'adversarialmnist3d': 0.892, 'nodulemnist3d': 0.913, 'synapsemnist3d': 0.975,
    'fracturemnist3d': 0.871, 'spleenmnist3d': 0.973, 'abasemnist3d': 0.889
}

all_results = {}

def is_3d(ds_name):
    return ds_name.endswith('3d')

def is_multilabel(ds_name):
    """ChestMNIST is multi-label (14 diseases)"""
    return ds_name == 'chestmnist'

def safe_target_processing(target, multilabel=False):
    if multilabel:
        return target.float()
    else:
        if target.ndim > 1:
            target = target.squeeze(-1)
        if target.ndim == 0:
            target = target.unsqueeze(0)
        return target.long()

def get_2d_transform():
    return transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

def get_3d_transform_2_5d():
    def preprocess_3d_to_2_5d(volume):
        if volume.ndim == 4 and volume.shape[0] == 1:
            volume = volume[0]
        if volume.ndim != 3:
            volume = volume.squeeze()
        D, H, W = volume.shape
        idx1, idx2, idx3 = int(D*0.25), int(D*0.50), int(D*0.75)
        slice1 = volume[idx1].astype(np.float32) / 255.0
        slice2 = volume[idx2].astype(np.float32) / 255.0
        slice3 = volume[idx3].astype(np.float32) / 255.0
        from scipy.ndimage import zoom
        zoom_factors = (224/H, 224/W)
        slice1 = zoom(slice1, zoom_factors, order=1)
        slice2 = zoom(slice2, zoom_factors, order=1)
        slice3 = zoom(slice3, zoom_factors, order=1)
        rgb_img = np.stack([slice1, slice2, slice3], axis=0)
        return torch.tensor(rgb_img, dtype=torch.float32)
    return transforms.Compose([
        transforms.Lambda(preprocess_3d_to_2_5d),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

def get_resnet50(num_classes):
    model = models.resnet50(weights='IMAGENET1K_V2')
    model.fc = nn.Linear(2048, num_classes)
    return model

def train_single_dataset(ds_name, epochs=30, patience=5):
    print(f"\n{'='*70}")
    print(f"🔬 ResNet-50 {'2.5D' if is_3d(ds_name) else '2D'}: {ds_name}")
    print(f"{'='*70}")

    try:
        info = INFO[ds_name]
        num_classes = len(info['label'])
        multilabel = is_multilabel(ds_name)
        if multilabel:
            print(f"⚠️  Multi-label dataset: {num_classes} classes")
    except:
        print(f"❌ NOT FOUND: {ds_name}")
        return 0.5

    transform = get_3d_transform_2_5d() if is_3d(ds_name) else get_2d_transform()
    as_rgb = not is_3d(ds_name)

    try:
        module = __import__('medmnist', fromlist=[info['python_class']])
        DataClass = getattr(module, info['python_class'])
        train_ds = DataClass(split='train', transform=transform, download=True, as_rgb=as_rgb)
        val_ds = DataClass(split='val', transform=transform, download=True, as_rgb=as_rgb)
        test_ds = DataClass(split='test', transform=transform, download=True, as_rgb=as_rgb)
        print(f"✅ Train: {len(train_ds):,} | Val: {len(val_ds):,} | Test: {len(test_ds):,}")
    except Exception as e:
        print(f"❌ Load error: {e}")
        return 0.5

    batch = 64
    train_loader = DataLoader(train_ds, batch_size=batch, shuffle=True, num_workers=2, pin_memory=True)
    val_loader = DataLoader(val_ds, batch_size=batch, shuffle=False, num_workers=2, pin_memory=True)
    test_loader = DataLoader(test_ds, batch_size=batch, shuffle=False, num_workers=2, pin_memory=True)

    model = get_resnet50(num_classes)
    model = model.to(device)
    
    # Freeze initial layers for faster convergence
    for param in list(model.parameters())[:-60]:
        param.requires_grad = False

    trainable = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.AdamW(trainable, lr=1e-3, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    best_auc = 0
    best_state = None
    patience_counter = 0  # Initialize patience counter
    start_time = time.time()

    for epoch in range(epochs):
        model.train()
        train_loss = 0

        for data, target in train_loader:
            data, target = data.to(device), target.to(device)
            target = safe_target_processing(target, multilabel)

            min_b = min(data.size(0), target.size(0))
            data, target = data[:min_b], target[:min_b]

            optimizer.zero_grad()
            output = model(data)

            if multilabel:
                loss = F.binary_cross_entropy_with_logits(output, target)
            else:
                loss = F.cross_entropy(output, target)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            train_loss += loss.item()

        scheduler.step()

        # Validation
        model.eval()
        val_preds, val_targets = [], []
        with torch.no_grad():
            for data, target in val_loader:
                data, target = data.to(device), target.to(device)
                target = safe_target_processing(target, multilabel)

                min_b = min(data.size(0), target.size(0))
                data, target = data[:min_b], target[:min_b]

                if multilabel:
                    prob = torch.sigmoid(model(data))
                else:
                    prob = F.softmax(model(data), dim=1)

                val_preds.extend(prob.cpu().numpy())
                val_targets.extend(target.cpu().numpy())

        val_preds = np.array(val_preds)
        val_targets = np.array(val_targets)

        try:
            if multilabel:
                val_auc = roc_auc_score(val_targets, val_preds, average='macro')
            elif num_classes > 2:
                val_auc = roc_auc_score(val_targets, val_preds, multi_class='ovr')
            else:
                val_auc = roc_auc_score(val_targets, val_preds[:, 1])
        except:
            val_auc = 0.5

        elapsed = time.time() - start_time
        print(f"  Epoch {epoch+1}/{epochs}: Loss={train_loss/len(train_loader):.3f} | AUC={val_auc:.4f} | Best={best_auc:.4f} | Patience={patience_counter}/{patience}")

        # EARLY STOPPING CHECK
        if val_auc > best_auc:
            best_auc = val_auc
            best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            patience_counter = 0  # Reset counter on improvement
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"🛑 Early stopping triggered at epoch {epoch+1}")
                break

    # Test
    if best_state:
        model.load_state_dict(best_state)
    model.eval()

    test_preds, test_targets = [], []
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            target = safe_target_processing(target, multilabel)

            min_b = min(data.size(0), target.size(0))
            data, target = data[:min_b], target[:min_b]

            if multilabel:
                prob = torch.sigmoid(model(data))
            else:
                prob = F.softmax(model(data), dim=1)

            test_preds.extend(prob.cpu().numpy())
            test_targets.extend(target.cpu().numpy())

    test_preds = np.array(test_preds)
    test_targets = np.array(test_targets)

    try:
        if multilabel:
            test_auc = roc_auc_score(test_targets, test_preds, average='macro')
        elif num_classes > 2:
            test_auc = roc_auc_score(test_targets, test_preds, multi_class='ovr')
        else:
            test_auc = roc_auc_score(test_targets, test_preds[:, 1])
    except:
        test_auc = 0.5

    bench = benchmarks.get(ds_name, 0)
    gap = test_auc - bench

    print(f"✅ {ds_name} | Test AUC: {test_auc:.4f} | Bench: {bench:.3f} | Gap: {gap:+.4f}")
    all_results[ds_name] = test_auc
    return test_auc

# ALL 18 DATASETS
all_datasets = [
    # 2D
    'pathmnist','chestmnist','dermamnist','octmnist','pneumoniamnist','retinamnist',
    'breastmnist','bloodmnist','tissuemnist','organamnist','organcmnist','organsmnist',
    # 3D
    'adversarialmnist3d','nodulemnist3d','synapsemnist3d','fracturemnist3d','spleenmnist3d','abasemnist3d'
]

print("\n🚀 STARTING TRAINING LOOP")

for ds in all_datasets:
    if os.path.exists(f'{ds}_best.pth'):
        os.remove(f'{ds}_best.pth')

for ds_name in all_datasets:
    try:
        train_single_dataset(ds_name, epochs=30, patience=5)
        torch.cuda.empty_cache()
    except Exception as e:
        print(f"❌ {ds_name} FAILED: {str(e)[:100]}")
        all_results[ds_name] = 0.5

print("\n" + "="*80)
print("🎯 FINAL RESULTS (30 Epochs + Early Stopping)")
print("="*80)
print(f"{'Dataset':<20} {'AUC':<10} {'Benchmark':<10} {'Gap':<10}")
print("-"*60)
for ds in all_datasets:
    bench = benchmarks.get(ds, 0)
    auc = all_results.get(ds, 0.5)
    gap = auc - bench
    status = "✅" if gap > -0.1 else "🔴"
    print(f"{ds:<20} {auc:<10.4f} {bench:<10.3f} {gap:+10.4f} {status}")

avg_auc = np.mean(list(all_results.values()))
print("="*80)
print(f"📈 Average AUC: {avg_auc:.4f}")
print("="*80)
# Out:
# ================================================================================
# 🚀 PRODUCTION: ALL 18 MEDMNIST DATASETS (2D+2.5D ResNet-50)
#    CONFIG: 30 Epochs | Early Stopping (Patience=5)
# ================================================================================
# Device: cuda
#
# 🚀 STARTING TRAINING LOOP
#
# ======================================================================
# 🔬 ResNet-50 2D: pathmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\pathmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pathmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pathmnist.npz
# ✅ Train: 89,996 | Val: 10,004 | Test: 7,180
#   Epoch 1/30: Loss=0.155 | AUC=0.9981 | Best=0.0000 | Patience=0/5
#   Epoch 2/30: Loss=0.057 | AUC=0.9997 | Best=0.9981 | Patience=0/5
#   Epoch 3/30: Loss=0.034 | AUC=0.9997 | Best=0.9997 | Patience=0/5
#   Epoch 4/30: Loss=0.026 | AUC=0.9996 | Best=0.9997 | Patience=1/5
#   Epoch 5/30: Loss=0.017 | AUC=0.9998 | Best=0.9997 | Patience=2/5
#   Epoch 6/30: Loss=0.015 | AUC=0.9976 | Best=0.9998 | Patience=0/5
#   Epoch 7/30: Loss=0.013 | AUC=0.9998 | Best=0.9998 | Patience=1/5
#   Epoch 8/30: Loss=0.010 | AUC=0.9997 | Best=0.9998 | Patience=0/5
#   Epoch 9/30: Loss=0.007 | AUC=0.9997 | Best=0.9998 | Patience=1/5
#   Epoch 10/30: Loss=0.008 | AUC=0.9971 | Best=0.9998 | Patience=2/5
#   Epoch 11/30: Loss=0.006 | AUC=0.9995 | Best=0.9998 | Patience=3/5
#   Epoch 12/30: Loss=0.005 | AUC=0.9997 | Best=0.9998 | Patience=4/5
# 🛑 Early stopping triggered at epoch 12
# ✅ pathmnist | Test AUC: 0.9877 | Bench: 0.989 | Gap: -0.0013
#
# ======================================================================
# 🔬 ResNet-50 2D: chestmnist
# ======================================================================
# ⚠️  Multi-label dataset: 14 classes
# Using downloaded and verified file: C:\Users\User\.medmnist\chestmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\chestmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\chestmnist.npz
# ✅ Train: 78,468 | Val: 11,219 | Test: 22,433
#   Epoch 1/30: Loss=0.168 | AUC=0.7597 | Best=0.0000 | Patience=0/5
#   Epoch 2/30: Loss=0.158 | AUC=0.7596 | Best=0.7597 | Patience=0/5
#   Epoch 3/30: Loss=0.149 | AUC=0.7600 | Best=0.7597 | Patience=1/5
#   Epoch 4/30: Loss=0.129 | AUC=0.7453 | Best=0.7600 | Patience=0/5
#   Epoch 5/30: Loss=0.091 | AUC=0.7185 | Best=0.7600 | Patience=1/5
#   Epoch 6/30: Loss=0.050 | AUC=0.7062 | Best=0.7600 | Patience=2/5
#   Epoch 7/30: Loss=0.026 | AUC=0.7035 | Best=0.7600 | Patience=3/5
#   Epoch 8/30: Loss=0.017 | AUC=0.6971 | Best=0.7600 | Patience=4/5
# 🛑 Early stopping triggered at epoch 8
# ✅ chestmnist | Test AUC: 0.7598 | Bench: 0.773 | Gap: -0.0132
#
# ======================================================================
# 🔬 ResNet-50 2D: dermamnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\dermamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\dermamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\dermamnist.npz
# ✅ Train: 7,007 | Val: 1,003 | Test: 2,005
#   Epoch 1/30: Loss=0.785 | AUC=0.9214 | Best=0.0000 | Patience=0/5
#   Epoch 2/30: Loss=0.567 | AUC=0.9104 | Best=0.9214 | Patience=0/5
#   Epoch 3/30: Loss=0.374 | AUC=0.9159 | Best=0.9214 | Patience=1/5
#   Epoch 4/30: Loss=0.183 | AUC=0.9253 | Best=0.9214 | Patience=2/5
#   Epoch 5/30: Loss=0.102 | AUC=0.9246 | Best=0.9253 | Patience=0/5
#   Epoch 6/30: Loss=0.058 | AUC=0.9181 | Best=0.9253 | Patience=1/5
#   Epoch 7/30: Loss=0.040 | AUC=0.9295 | Best=0.9253 | Patience=2/5
#   Epoch 8/30: Loss=0.028 | AUC=0.9322 | Best=0.9295 | Patience=0/5
#   Epoch 9/30: Loss=0.016 | AUC=0.9173 | Best=0.9322 | Patience=0/5
#   Epoch 10/30: Loss=0.017 | AUC=0.9216 | Best=0.9322 | Patience=1/5
#   Epoch 11/30: Loss=0.014 | AUC=0.9259 | Best=0.9322 | Patience=2/5
#   Epoch 12/30: Loss=0.009 | AUC=0.9314 | Best=0.9322 | Patience=3/5
#   Epoch 13/30: Loss=0.002 | AUC=0.9277 | Best=0.9322 | Patience=4/5
# 🛑 Early stopping triggered at epoch 13
# ✅ dermamnist | Test AUC: 0.9164 | Bench: 0.920 | Gap: -0.0036
#
# ======================================================================
# 🔬 ResNet-50 2D: octmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\octmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\octmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\octmnist.npz
# ✅ Train: 97,477 | Val: 10,832 | Test: 1,000
#   Epoch 1/30: Loss=0.355 | AUC=0.9657 | Best=0.0000 | Patience=0/5
#   Epoch 2/30: Loss=0.253 | AUC=0.9715 | Best=0.9657 | Patience=0/5
#   Epoch 3/30: Loss=0.188 | AUC=0.9725 | Best=0.9715 | Patience=0/5
#   Epoch 4/30: Loss=0.125 | AUC=0.9716 | Best=0.9725 | Patience=0/5
#   Epoch 5/30: Loss=0.074 | AUC=0.9704 | Best=0.9725 | Patience=1/5
#   Epoch 6/30: Loss=0.049 | AUC=0.9693 | Best=0.9725 | Patience=2/5
#   Epoch 7/30: Loss=0.039 | AUC=0.9700 | Best=0.9725 | Patience=3/5
#   Epoch 8/30: Loss=0.034 | AUC=0.9707 | Best=0.9725 | Patience=4/5
# 🛑 Early stopping triggered at epoch 8
# ✅ octmnist | Test AUC: 0.9570 | Bench: 0.958 | Gap: -0.0010
#
# ======================================================================
# 🔬 ResNet-50 2D: pneumoniamnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\pneumoniamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pneumoniamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pneumoniamnist.npz
# ✅ Train: 4,708 | Val: 524 | Test: 624
#   Epoch 1/30: Loss=0.159 | AUC=0.9910 | Best=0.0000 | Patience=0/5
#   Epoch 2/30: Loss=0.049 | AUC=0.9922 | Best=0.9910 | Patience=0/5
#   Epoch 3/30: Loss=0.028 | AUC=0.9964 | Best=0.9922 | Patience=0/5
#   Epoch 4/30: Loss=0.012 | AUC=0.9941 | Best=0.9964 | Patience=0/5
#   Epoch 5/30: Loss=0.016 | AUC=0.9925 | Best=0.9964 | Patience=1/5
#   Epoch 6/30: Loss=0.012 | AUC=0.9944 | Best=0.9964 | Patience=2/5
#   Epoch 7/30: Loss=0.013 | AUC=0.9940 | Best=0.9964 | Patience=3/5
#   Epoch 8/30: Loss=0.008 | AUC=0.9944 | Best=0.9964 | Patience=4/5
# 🛑 Early stopping triggered at epoch 8
# ✅ pneumoniamnist | Test AUC: 0.9674 | Bench: 0.962 | Gap: +0.0054
#
# ======================================================================
# 🔬 ResNet-50 2D: retinamnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\retinamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\retinamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\retinamnist.npz
# ✅ Train: 1,080 | Val: 120 | Test: 400
#   Epoch 1/30: Loss=1.242 | AUC=0.7847 | Best=0.0000 | Patience=0/5
#   Epoch 2/30: Loss=0.889 | AUC=0.7816 | Best=0.7847 | Patience=0/5
#   Epoch 3/30: Loss=0.495 | AUC=0.6863 | Best=0.7847 | Patience=1/5
#   Epoch 4/30: Loss=0.249 | AUC=0.6625 | Best=0.7847 | Patience=2/5
#   Epoch 5/30: Loss=0.201 | AUC=0.7322 | Best=0.7847 | Patience=3/5
#   Epoch 6/30: Loss=0.138 | AUC=0.7065 | Best=0.7847 | Patience=4/5
# 🛑 Early stopping triggered at epoch 6
# ✅ retinamnist | Test AUC: 0.7339 | Bench: 0.716 | Gap: +0.0179
#
# ======================================================================
# 🔬 ResNet-50 2D: breastmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\breastmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\breastmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\breastmnist.npz
# ✅ Train: 546 | Val: 78 | Test: 156
#   Epoch 1/30: Loss=0.524 | AUC=0.8108 | Best=0.0000 | Patience=0/5
#   Epoch 2/30: Loss=0.175 | AUC=0.7978 | Best=0.8108 | Patience=0/5
#   Epoch 3/30: Loss=0.035 | AUC=0.7886 | Best=0.8108 | Patience=1/5
#   Epoch 4/30: Loss=0.005 | AUC=0.8630 | Best=0.8108 | Patience=2/5
#   Epoch 5/30: Loss=0.013 | AUC=0.9006 | Best=0.8630 | Patience=0/5
#   Epoch 6/30: Loss=0.015 | AUC=0.9323 | Best=0.9006 | Patience=0/5
#   Epoch 7/30: Loss=0.006 | AUC=0.9624 | Best=0.9323 | Patience=0/5
#   Epoch 8/30: Loss=0.008 | AUC=0.9390 | Best=0.9624 | Patience=0/5
#   Epoch 9/30: Loss=0.014 | AUC=0.9231 | Best=0.9624 | Patience=1/5
#   Epoch 10/30: Loss=0.030 | AUC=0.9215 | Best=0.9624 | Patience=2/5
#   Epoch 11/30: Loss=0.027 | AUC=0.8672 | Best=0.9624 | Patience=3/5
#   Epoch 12/30: Loss=0.017 | AUC=0.8830 | Best=0.9624 | Patience=4/5
# 🛑 Early stopping triggered at epoch 12
# ✅ breastmnist | Test AUC: 0.8989 | Bench: 0.866 | Gap: +0.0329
#
# ======================================================================
# 🔬 ResNet-50 2D: bloodmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\bloodmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\bloodmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\bloodmnist.npz
# ✅ Train: 11,959 | Val: 1,712 | Test: 3,421
#   Epoch 1/30: Loss=0.359 | AUC=0.9966 | Best=0.0000 | Patience=0/5
#   Epoch 2/30: Loss=0.132 | AUC=0.9968 | Best=0.9966 | Patience=0/5
#   Epoch 3/30: Loss=0.058 | AUC=0.9967 | Best=0.9968 | Patience=0/5
#   Epoch 4/30: Loss=0.032 | AUC=0.9984 | Best=0.9968 | Patience=1/5
#   Epoch 5/30: Loss=0.017 | AUC=0.9978 | Best=0.9984 | Patience=0/5
#   Epoch 6/30: Loss=0.005 | AUC=0.9981 | Best=0.9984 | Patience=1/5
#   Epoch 7/30: Loss=0.014 | AUC=0.9981 | Best=0.9984 | Patience=2/5
#   Epoch 8/30: Loss=0.016 | AUC=0.9981 | Best=0.9984 | Patience=3/5
#   Epoch 9/30: Loss=0.006 | AUC=0.9978 | Best=0.9984 | Patience=4/5
# 🛑 Early stopping triggered at epoch 9
# ✅ bloodmnist | Test AUC: 0.9975 | Bench: 0.998 | Gap: -0.0005
#
# ======================================================================
# 🔬 ResNet-50 2D: tissuemnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\tissuemnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\tissuemnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\tissuemnist.npz
# ✅ Train: 165,466 | Val: 23,640 | Test: 47,280
#   Epoch 1/30: Loss=1.043 | AUC=0.9183 | Best=0.0000 | Patience=0/5
#   Epoch 2/30: Loss=0.884 | AUC=0.9238 | Best=0.9183 | Patience=0/5
#   Epoch 3/30: Loss=0.761 | AUC=0.9257 | Best=0.9238 | Patience=0/5
#   Epoch 4/30: Loss=0.579 | AUC=0.9162 | Best=0.9257 | Patience=0/5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 269
#     267 for ds_name in all_datasets:
#     268     try:
# --> 269         train_single_dataset(ds_name, epochs=30, patience=5)
#     270         torch.cuda.empty_cache()
#     271     except Exception as e:
#
# Cell In[2], line 160, in train_single_dataset(ds_name, epochs, patience)
#     158     torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#     159     optimizer.step()
# --> 160     train_loss += loss.item()
#     162 scheduler.step()
#     164 # Validation
#
# KeyboardInterrupt:

# %%
# !pip install -q medmnist pillow scipy tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import transforms, models
from medmnist import INFO
import numpy as np
from sklearn.metrics import roc_auc_score
import time
import os
import warnings
warnings.filterwarnings('ignore')

print("="*80)
print("🚀 OPTIMAL: ACS (All Slices) for 3D + ResNet-50 for 2D")
print("   CONFIG: 30 Epochs | Early Stopping (Patience=5)")
print("="*80)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")

benchmarks = {
    'pathmnist': 0.989, 'chestmnist': 0.773, 'dermamnist': 0.920, 'octmnist': 0.958,
    'pneumoniamnist': 0.962, 'retinamnist': 0.716, 'breastmnist': 0.866, 'bloodmnist': 0.998,
    'tissuemnist': 0.932, 'organamnist': 0.998, 'organcmnist': 0.993, 'organsmnist': 0.975,
    'adrenalmnist3d': 0.889, 'fracturemnist3d': 0.871, 'nodulemnist3d': 0.913, 
    'organmnist3d': 0.995, 'synapsemnist3d': 0.975, 'vesselmnist3d': 0.899
}

all_results = {}

def is_3d(ds_name):
    return ds_name.endswith('3d')

def is_multilabel(ds_name):
    return ds_name == 'chestmnist'

def safe_target_processing(target, multilabel=False):
    if multilabel:
        return target.float()
    else:
        if target.ndim > 1:
            target = target.squeeze(-1)
        if target.ndim == 0:
            target = target.unsqueeze(0)
        return target.long()

def get_2d_transform():
    return transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

def preprocess_3d_acs(volume):
    """ACS: Process ALL slices, not just 3"""
    if volume.ndim == 4 and volume.shape[0] == 1:
        volume = volume[0]
    if volume.ndim != 3:
        volume = volume.squeeze()
    
    D, H, W = volume.shape
    volume = volume.astype(np.float32) / 255.0
    
    from scipy.ndimage import zoom
    zoom_factors = (1.0, 224/H, 224/W)  # Keep all slices, resize H,W
    resized = zoom(volume, zoom_factors, order=1)
    
    # Convert to RGB by repeating: (D,224,224) -> (D,3,224,224)
    slices = []
    for i in range(resized.shape[0]):
        slice_rgb = np.stack([resized[i]]*3, axis=0)  # (3,224,224)
        slices.append(slice_rgb)
    
    return torch.tensor(np.array(slices), dtype=torch.float32)  # (D,3,224,224)

def get_3d_transform_acs():
    return transforms.Compose([
        transforms.Lambda(preprocess_3d_acs),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

class ResNet50_ACS(nn.Module):
    """ResNet-50 with ACS: processes all slices and aggregates"""
    def __init__(self, num_classes):
        super().__init__()
        self.resnet = models.resnet50(weights='IMAGENET1K_V2')
        self.resnet.fc = nn.Identity()  # Remove final FC
        self.fc = nn.Linear(2048, num_classes)
        
    def forward(self, x):
        # x shape: (B, D, 3, 224, 224) for 3D or (B, 3, 224, 224) for 2D
        if x.ndim == 5:  # 3D data
            B, D, C, H, W = x.shape
            x = x.view(B*D, C, H, W)  # (B*D, 3, 224, 224)
            features = self.resnet(x)  # (B*D, 2048)
            features = features.view(B, D, -1)  # (B, D, 2048)
            features = features.mean(dim=1)  # (B, 2048) - average pooling
        else:  # 2D data
            features = self.resnet(x)  # (B, 2048)
        
        return self.fc(features)

def get_resnet50(num_classes, is_3d_data):
    if is_3d_data:
        return ResNet50_ACS(num_classes)
    else:
        model = models.resnet50(weights='IMAGENET1K_V2')
        model.fc = nn.Linear(2048, num_classes)
        return model

def train_single_dataset(ds_name, epochs=30, patience=5):
    print(f"\n{'='*70}")
    print(f"🔬 ResNet-50 {'ACS' if is_3d(ds_name) else '2D'}: {ds_name}")
    print(f"{'='*70}")
    
    try:
        info = INFO[ds_name]
        num_classes = len(info['label'])
        multilabel = is_multilabel(ds_name)
        if multilabel:
            print(f"⚠️  Multi-label: {num_classes} classes")
    except:
        print(f"❌ NOT FOUND: {ds_name}")
        return 0.5
    
    transform = get_3d_transform_acs() if is_3d(ds_name) else get_2d_transform()
    as_rgb = not is_3d(ds_name)
    
    try:
        module = __import__('medmnist', fromlist=[info['python_class']])
        DataClass = getattr(module, info['python_class'])
        train_ds = DataClass(split='train', transform=transform, download=True, as_rgb=as_rgb)
        val_ds = DataClass(split='val', transform=transform, download=True, as_rgb=as_rgb)
        test_ds = DataClass(split='test', transform=transform, download=True, as_rgb=as_rgb)
        print(f"✅ Train: {len(train_ds):,} | Val: {len(val_ds):,} | Test: {len(test_ds):,}")
    except Exception as e:
        print(f"❌ Load error: {e}")
        return 0.5
    
    # Smaller batch for 3D (more memory)
    batch = 16 if is_3d(ds_name) else 64
    train_loader = DataLoader(train_ds, batch_size=batch, shuffle=True, num_workers=0, pin_memory=True)
    val_loader = DataLoader(val_ds, batch_size=batch, shuffle=False, num_workers=0, pin_memory=True)
    test_loader = DataLoader(test_ds, batch_size=batch, shuffle=False, num_workers=0, pin_memory=True)
    
    model = get_resnet50(num_classes, is_3d(ds_name))
    model = model.to(device)
    print(f"✅ Model: {sum(p.numel() for p in model.parameters()):,} params")
    
    # Freeze early layers
    for param in list(model.parameters())[:-60]:
        param.requires_grad = False
    
    trainable = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.AdamW(trainable, lr=1e-3, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
    
    best_auc = 0
    best_state = None
    patience_counter = 0
    start_time = time.time()
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        
        for data, target in train_loader:
            data, target = data.to(device), target.to(device)
            target = safe_target_processing(target, multilabel)
            
            min_b = min(data.size(0), target.size(0))
            data, target = data[:min_b], target[:min_b]
            
            optimizer.zero_grad()
            output = model(data)
            
            if multilabel:
                loss = F.binary_cross_entropy_with_logits(output, target)
            else:
                loss = F.cross_entropy(output, target)
            
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            train_loss += loss.item()
        
        scheduler.step()
        
        model.eval()
        val_preds, val_targets = [], []
        with torch.no_grad():
            for data, target in val_loader:
                data, target = data.to(device), target.to(device)
                target = safe_target_processing(target, multilabel)
                
                min_b = min(data.size(0), target.size(0))
                data, target = data[:min_b], target[:min_b]
                
                if multilabel:
                    prob = torch.sigmoid(model(data))
                else:
                    prob = F.softmax(model(data), dim=1)
                
                val_preds.extend(prob.cpu().numpy())
                val_targets.extend(target.cpu().numpy())
        
        val_preds = np.array(val_preds)
        val_targets = np.array(val_targets)
        
        try:
            if multilabel:
                val_auc = roc_auc_score(val_targets, val_preds, average='macro')
            elif num_classes > 2:
                val_auc = roc_auc_score(val_targets, val_preds, multi_class='ovr')
            else:
                val_auc = roc_auc_score(val_targets, val_preds[:, 1])
        except:
            val_auc = 0.5
        
        elapsed = time.time() - start_time
        print(f"  Epoch {epoch+1}/{epochs}: Loss={train_loss/len(train_loader):.3f} | AUC={val_auc:.4f} | Best={best_auc:.4f}")
        
        # EARLY STOPPING
        if val_auc > best_auc:
            best_auc = val_auc
            best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"  🛑 Early stopping triggered at epoch {epoch+1}")
                break
    
    if best_state:
        model.load_state_dict(best_state)
    model.eval()
    
    test_preds, test_targets = [], []
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            target = safe_target_processing(target, multilabel)
            
            min_b = min(data.size(0), target.size(0))
            data, target = data[:min_b], target[:min_b]
            
            if multilabel:
                prob = torch.sigmoid(model(data))
            else:
                prob = F.softmax(model(data), dim=1)
            
            test_preds.extend(prob.cpu().numpy())
            test_targets.extend(target.cpu().numpy())
    
    test_preds = np.array(test_preds)
    test_targets = np.array(test_targets)
    
    try:
        if multilabel:
            test_auc = roc_auc_score(test_targets, test_preds, average='macro')
        elif num_classes > 2:
            test_auc = roc_auc_score(test_targets, test_preds, multi_class='ovr')
        else:
            test_auc = roc_auc_score(test_targets, test_preds[:, 1])
    except:
        test_auc = 0.5
    
    total_time = time.time() - start_time
    bench = benchmarks.get(ds_name, 0)
    gap = test_auc - bench
    
    print(f"✅ {ds_name} | AUC: {test_auc:.4f} | Bench: {bench:.3f} | Gap: {gap:+.4f}")
    all_results[ds_name] = test_auc
    return test_auc

all_datasets = [
    'adrenalmnist3d', 'fracturemnist3d', 'nodulemnist3d', 
    'organmnist3d', 'synapsemnist3d', 'vesselmnist3d',
    'pathmnist', 'chestmnist', 'dermamnist', 'octmnist', 'pneumoniamnist', 'retinamnist',
    'breastmnist', 'bloodmnist', 'tissuemnist', 'organamnist', 'organcmnist', 'organsmnist'
]

print("\n🚀 ACS (All Slices) for 3D | 30 EPOCHS (Patience=5) | 3D FIRST → 2D AFTER\n")

for ds in all_datasets:
    if os.path.exists(f'{ds}_best.pth'):
        os.remove(f'{ds}_best.pth')

for ds_name in all_datasets:
    try:
        train_single_dataset(ds_name, epochs=30, patience=5)
        torch.cuda.empty_cache()
    except Exception as e:
        print(f"❌ {ds_name} FAILED: {str(e)[:100]}")
        all_results[ds_name] = 0.5

print("\n" + "="*80)
print("🎯 FINAL RESULTS (ACS for 3D)")
print("="*80)
print(f"{'Dataset':<20} {'AUC':<10} {'Benchmark':<10} {'Gap':<10}")
print("-"*60)
print("\n📊 3D RESULTS (ACS - All Slices)")
print("-"*60)
for ds in all_datasets[:6]:
    bench = benchmarks.get(ds, 0)
    auc = all_results.get(ds, 0.5)
    gap = auc - bench
    status = "✅" if gap > -0.1 else "🔴"
    print(f"{ds:<20} {auc:<10.4f} {bench:<10.3f} {gap:+10.4f} {status}")
print("\n📊 2D RESULTS")
print("-"*60)
for ds in all_datasets[6:]:
    bench = benchmarks.get(ds, 0)
    auc = all_results.get(ds, 0.5)
    gap = auc - bench
    status = "✅" if gap > -0.1 else "🔴"
    print(f"{ds:<20} {auc:<10.4f} {bench:<10.3f} {gap:+10.4f} {status}")
avg_auc = np.mean(list(all_results.values()))
print("="*80)
print(f"📈 Average AUC: {avg_auc:.4f}")
print("="*80)
# Out:
# ================================================================================
# 🚀 OPTIMAL: ACS (All Slices) for 3D + ResNet-50 for 2D
#    CONFIG: 30 Epochs | Early Stopping (Patience=5)
# ================================================================================
# Device: cuda
#
# 🚀 ACS (All Slices) for 3D | 30 EPOCHS (Patience=5) | 3D FIRST → 2D AFTER
#
#
# ======================================================================
# 🔬 ResNet-50 ACS: adrenalmnist3d
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\adrenalmnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\adrenalmnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\adrenalmnist3d.npz
# ✅ Train: 1,188 | Val: 98 | Test: 298
# ✅ Model: 23,512,130 params
#   Epoch 1/30: Loss=0.564 | AUC=0.6896 | Best=0.0000
#   Epoch 2/30: Loss=0.470 | AUC=0.8678 | Best=0.6896
#   Epoch 3/30: Loss=0.438 | AUC=0.8947 | Best=0.8678
#   Epoch 4/30: Loss=0.402 | AUC=0.8858 | Best=0.8947
#   Epoch 5/30: Loss=0.390 | AUC=0.8618 | Best=0.8947
#   Epoch 6/30: Loss=0.380 | AUC=0.8708 | Best=0.8947
#   Epoch 7/30: Loss=0.340 | AUC=0.8319 | Best=0.8947
#   Epoch 8/30: Loss=0.284 | AUC=0.8600 | Best=0.8947
#   🛑 Early stopping triggered at epoch 8
# ✅ adrenalmnist3d | AUC: 0.8418 | Bench: 0.889 | Gap: -0.0472
#
# ======================================================================
# 🔬 ResNet-50 ACS: fracturemnist3d
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\fracturemnist3d.npz
# ✅ Train: 1,027 | Val: 103 | Test: 240
# ✅ Model: 23,514,179 params
#   Epoch 1/30: Loss=1.019 | AUC=0.6437 | Best=0.0000
#   Epoch 2/30: Loss=0.953 | AUC=0.6391 | Best=0.6437
#   Epoch 3/30: Loss=0.932 | AUC=0.7014 | Best=0.6437
#   Epoch 4/30: Loss=0.902 | AUC=0.6862 | Best=0.7014
#   Epoch 5/30: Loss=0.893 | AUC=0.6436 | Best=0.7014
#   Epoch 6/30: Loss=0.852 | AUC=0.6582 | Best=0.7014
#   Epoch 7/30: Loss=0.846 | AUC=0.6988 | Best=0.7014
#   Epoch 8/30: Loss=0.836 | AUC=0.7105 | Best=0.7014
#   Epoch 9/30: Loss=0.736 | AUC=0.6642 | Best=0.7105
#   Epoch 10/30: Loss=0.705 | AUC=0.6785 | Best=0.7105
#   Epoch 11/30: Loss=0.619 | AUC=0.6966 | Best=0.7105
#   Epoch 12/30: Loss=0.588 | AUC=0.6692 | Best=0.7105
#   Epoch 13/30: Loss=0.421 | AUC=0.6595 | Best=0.7105
#   🛑 Early stopping triggered at epoch 13
# ✅ fracturemnist3d | AUC: 0.7242 | Bench: 0.871 | Gap: -0.1468
#
# ======================================================================
# 🔬 ResNet-50 ACS: nodulemnist3d
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\nodulemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\nodulemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\nodulemnist3d.npz
# ✅ Train: 1,158 | Val: 165 | Test: 310
# ✅ Model: 23,512,130 params
#   Epoch 1/30: Loss=0.472 | AUC=0.8386 | Best=0.0000
#   Epoch 2/30: Loss=0.400 | AUC=0.8451 | Best=0.8386
#   Epoch 3/30: Loss=0.368 | AUC=0.8225 | Best=0.8451
#   Epoch 4/30: Loss=0.368 | AUC=0.7979 | Best=0.8451
#   Epoch 5/30: Loss=0.336 | AUC=0.8496 | Best=0.8451
#   Epoch 6/30: Loss=0.330 | AUC=0.7911 | Best=0.8496
#   Epoch 7/30: Loss=0.308 | AUC=0.8148 | Best=0.8496
#   Epoch 8/30: Loss=0.269 | AUC=0.8256 | Best=0.8496
#   Epoch 9/30: Loss=0.254 | AUC=0.8378 | Best=0.8496
#   Epoch 10/30: Loss=0.218 | AUC=0.8666 | Best=0.8496
#   Epoch 11/30: Loss=0.183 | AUC=0.8409 | Best=0.8666
#   Epoch 12/30: Loss=0.159 | AUC=0.8564 | Best=0.8666
#   Epoch 13/30: Loss=0.120 | AUC=0.8637 | Best=0.8666
#   Epoch 14/30: Loss=0.101 | AUC=0.8269 | Best=0.8666
#   Epoch 15/30: Loss=0.076 | AUC=0.8544 | Best=0.8666
#   🛑 Early stopping triggered at epoch 15
# ✅ nodulemnist3d | AUC: 0.8954 | Bench: 0.913 | Gap: -0.0176
#
# ======================================================================
# 🔬 ResNet-50 ACS: organmnist3d
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\organmnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organmnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organmnist3d.npz
# ✅ Train: 971 | Val: 161 | Test: 610
# ✅ Model: 23,530,571 params
#   Epoch 1/30: Loss=1.213 | AUC=0.6641 | Best=0.0000
#   Epoch 2/30: Loss=0.739 | AUC=0.9875 | Best=0.6641
#   Epoch 3/30: Loss=0.624 | AUC=0.9900 | Best=0.9875
#   Epoch 4/30: Loss=0.485 | AUC=0.9790 | Best=0.9900
#   Epoch 5/30: Loss=0.456 | AUC=0.9919 | Best=0.9900
#   Epoch 6/30: Loss=0.419 | AUC=0.9929 | Best=0.9919
#   Epoch 7/30: Loss=0.392 | AUC=0.9850 | Best=0.9929
#   Epoch 8/30: Loss=0.332 | AUC=0.9924 | Best=0.9929
#   Epoch 9/30: Loss=0.315 | AUC=0.9943 | Best=0.9929
#   Epoch 10/30: Loss=0.261 | AUC=0.9921 | Best=0.9943
#   Epoch 11/30: Loss=0.228 | AUC=0.9938 | Best=0.9943
#   Epoch 12/30: Loss=0.184 | AUC=0.9944 | Best=0.9943
#   Epoch 13/30: Loss=0.169 | AUC=0.9920 | Best=0.9944
#   Epoch 14/30: Loss=0.121 | AUC=0.9966 | Best=0.9944
#   Epoch 15/30: Loss=0.077 | AUC=0.9956 | Best=0.9966
#   Epoch 16/30: Loss=0.093 | AUC=0.9945 | Best=0.9966
#   Epoch 17/30: Loss=0.080 | AUC=0.9964 | Best=0.9966
#   Epoch 18/30: Loss=0.031 | AUC=0.9965 | Best=0.9966
#   Epoch 19/30: Loss=0.028 | AUC=0.9964 | Best=0.9966
#   🛑 Early stopping triggered at epoch 19
# ✅ organmnist3d | AUC: 0.9741 | Bench: 0.995 | Gap: -0.0209
#
# ======================================================================
# 🔬 ResNet-50 ACS: synapsemnist3d
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\synapsemnist3d.npz
# ✅ Train: 1,230 | Val: 177 | Test: 352
# ✅ Model: 23,512,130 params
#   Epoch 1/30: Loss=0.501 | AUC=0.7847 | Best=0.0000
#   Epoch 2/30: Loss=0.349 | AUC=0.8700 | Best=0.7847
#   Epoch 3/30: Loss=0.288 | AUC=0.8835 | Best=0.8700
#   Epoch 4/30: Loss=0.194 | AUC=0.9060 | Best=0.8835
#   Epoch 5/30: Loss=0.163 | AUC=0.9005 | Best=0.9060
#   Epoch 6/30: Loss=0.099 | AUC=0.8894 | Best=0.9060
#   Epoch 7/30: Loss=0.066 | AUC=0.9016 | Best=0.9060
#   Epoch 8/30: Loss=0.039 | AUC=0.8995 | Best=0.9060
#   Epoch 9/30: Loss=0.033 | AUC=0.9032 | Best=0.9060
#   🛑 Early stopping triggered at epoch 9
# ✅ synapsemnist3d | AUC: 0.9149 | Bench: 0.975 | Gap: -0.0601
#
# ======================================================================
# 🔬 ResNet-50 ACS: vesselmnist3d
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\vesselmnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\vesselmnist3d.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\vesselmnist3d.npz
# ✅ Train: 1,335 | Val: 191 | Test: 382
# ✅ Model: 23,512,130 params
#   Epoch 1/30: Loss=0.341 | AUC=0.7803 | Best=0.0000
#   Epoch 2/30: Loss=0.280 | AUC=0.8653 | Best=0.7803
#   Epoch 3/30: Loss=0.247 | AUC=0.8389 | Best=0.8653
#   Epoch 4/30: Loss=0.230 | AUC=0.8607 | Best=0.8653
#   Epoch 5/30: Loss=0.191 | AUC=0.8653 | Best=0.8653
#   Epoch 6/30: Loss=0.158 | AUC=0.8445 | Best=0.8653
#   Epoch 7/30: Loss=0.113 | AUC=0.8497 | Best=0.8653
#   Epoch 8/30: Loss=0.109 | AUC=0.8897 | Best=0.8653
#   Epoch 9/30: Loss=0.055 | AUC=0.9091 | Best=0.8897
#   Epoch 10/30: Loss=0.042 | AUC=0.8897 | Best=0.9091
#   Epoch 11/30: Loss=0.033 | AUC=0.9096 | Best=0.9091
#   Epoch 12/30: Loss=0.019 | AUC=0.9150 | Best=0.9096
#   Epoch 13/30: Loss=0.004 | AUC=0.9029 | Best=0.9150
#   Epoch 14/30: Loss=0.010 | AUC=0.9086 | Best=0.9150
#   Epoch 15/30: Loss=0.014 | AUC=0.9032 | Best=0.9150
#   Epoch 16/30: Loss=0.017 | AUC=0.8916 | Best=0.9150
#   Epoch 17/30: Loss=0.001 | AUC=0.9181 | Best=0.9150
#   Epoch 18/30: Loss=0.006 | AUC=0.9072 | Best=0.9181
#   Epoch 19/30: Loss=0.003 | AUC=0.9091 | Best=0.9181
#   Epoch 20/30: Loss=0.001 | AUC=0.9104 | Best=0.9181
#   Epoch 21/30: Loss=0.001 | AUC=0.9126 | Best=0.9181
#   Epoch 22/30: Loss=0.001 | AUC=0.9003 | Best=0.9181
#   🛑 Early stopping triggered at epoch 22
# ✅ vesselmnist3d | AUC: 0.8913 | Bench: 0.899 | Gap: -0.0077
#
# ======================================================================
# 🔬 ResNet-50 2D: pathmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\pathmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pathmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pathmnist.npz
# ✅ Train: 89,996 | Val: 10,004 | Test: 7,180
# ✅ Model: 23,526,473 params
#   Epoch 1/30: Loss=0.158 | AUC=0.9985 | Best=0.0000
#   Epoch 2/30: Loss=0.059 | AUC=0.9992 | Best=0.9985
#   Epoch 3/30: Loss=0.036 | AUC=0.9997 | Best=0.9992
#   Epoch 4/30: Loss=0.024 | AUC=0.9998 | Best=0.9997
#   Epoch 5/30: Loss=0.016 | AUC=0.9975 | Best=0.9998
#   Epoch 6/30: Loss=0.015 | AUC=0.9994 | Best=0.9998
#   Epoch 7/30: Loss=0.013 | AUC=0.9996 | Best=0.9998
#   Epoch 8/30: Loss=0.010 | AUC=0.9997 | Best=0.9998
#   Epoch 9/30: Loss=0.009 | AUC=0.9994 | Best=0.9998
#   🛑 Early stopping triggered at epoch 9
# ✅ pathmnist | AUC: 0.9922 | Bench: 0.989 | Gap: +0.0032
#
# ======================================================================
# 🔬 ResNet-50 2D: chestmnist
# ======================================================================
# ⚠️  Multi-label: 14 classes
# Using downloaded and verified file: C:\Users\User\.medmnist\chestmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\chestmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\chestmnist.npz
# ✅ Train: 78,468 | Val: 11,219 | Test: 22,433
# ✅ Model: 23,536,718 params
#   Epoch 1/30: Loss=0.168 | AUC=0.7545 | Best=0.0000
#   Epoch 2/30: Loss=0.158 | AUC=0.7655 | Best=0.7545
#   Epoch 3/30: Loss=0.149 | AUC=0.7622 | Best=0.7655
#   Epoch 4/30: Loss=0.130 | AUC=0.7427 | Best=0.7655
#   Epoch 5/30: Loss=0.093 | AUC=0.7215 | Best=0.7655
#   Epoch 6/30: Loss=0.052 | AUC=0.7049 | Best=0.7655
#   Epoch 7/30: Loss=0.026 | AUC=0.7058 | Best=0.7655
#   🛑 Early stopping triggered at epoch 7
# ✅ chestmnist | AUC: 0.7669 | Bench: 0.773 | Gap: -0.0061
#
# ======================================================================
# 🔬 ResNet-50 2D: dermamnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\dermamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\dermamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\dermamnist.npz
# ✅ Train: 7,007 | Val: 1,003 | Test: 2,005
# ✅ Model: 23,522,375 params
#   Epoch 1/30: Loss=0.784 | AUC=0.9120 | Best=0.0000
#   Epoch 2/30: Loss=0.581 | AUC=0.9081 | Best=0.9120
#   Epoch 3/30: Loss=0.386 | AUC=0.9275 | Best=0.9120
#   Epoch 4/30: Loss=0.191 | AUC=0.9244 | Best=0.9275
#   Epoch 5/30: Loss=0.098 | AUC=0.9267 | Best=0.9275
#   Epoch 6/30: Loss=0.064 | AUC=0.9253 | Best=0.9275
#   Epoch 7/30: Loss=0.038 | AUC=0.9306 | Best=0.9275
#   Epoch 8/30: Loss=0.037 | AUC=0.9300 | Best=0.9306
#   Epoch 9/30: Loss=0.027 | AUC=0.9290 | Best=0.9306
#   Epoch 10/30: Loss=0.016 | AUC=0.9318 | Best=0.9306
#   Epoch 11/30: Loss=0.010 | AUC=0.9338 | Best=0.9318
#   Epoch 12/30: Loss=0.007 | AUC=0.9313 | Best=0.9338
#   Epoch 13/30: Loss=0.007 | AUC=0.9309 | Best=0.9338
#   Epoch 14/30: Loss=0.004 | AUC=0.9310 | Best=0.9338
#   Epoch 15/30: Loss=0.006 | AUC=0.9294 | Best=0.9338
#   Epoch 16/30: Loss=0.003 | AUC=0.9276 | Best=0.9338
#   🛑 Early stopping triggered at epoch 16
# ✅ dermamnist | AUC: 0.9243 | Bench: 0.920 | Gap: +0.0043
#
# ======================================================================
# 🔬 ResNet-50 2D: octmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\octmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\octmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\octmnist.npz
# ✅ Train: 97,477 | Val: 10,832 | Test: 1,000
# ✅ Model: 23,516,228 params
#   Epoch 1/30: Loss=0.351 | AUC=0.9625 | Best=0.0000
#   Epoch 2/30: Loss=0.251 | AUC=0.9698 | Best=0.9625
#   Epoch 3/30: Loss=0.190 | AUC=0.9730 | Best=0.9698
#   Epoch 4/30: Loss=0.124 | AUC=0.9697 | Best=0.9730
#   Epoch 5/30: Loss=0.075 | AUC=0.9705 | Best=0.9730
#   Epoch 6/30: Loss=0.052 | AUC=0.9712 | Best=0.9730
#   Epoch 7/30: Loss=0.040 | AUC=0.9696 | Best=0.9730
#   Epoch 8/30: Loss=0.033 | AUC=0.9704 | Best=0.9730
#   🛑 Early stopping triggered at epoch 8
# ✅ octmnist | AUC: 0.9586 | Bench: 0.958 | Gap: +0.0006
#
# ======================================================================
# 🔬 ResNet-50 2D: pneumoniamnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\pneumoniamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pneumoniamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\pneumoniamnist.npz
# ✅ Train: 4,708 | Val: 524 | Test: 624
# ✅ Model: 23,512,130 params
#   Epoch 1/30: Loss=0.160 | AUC=0.9894 | Best=0.0000
#   Epoch 2/30: Loss=0.049 | AUC=0.9930 | Best=0.9894
#   Epoch 3/30: Loss=0.027 | AUC=0.9917 | Best=0.9930
#   Epoch 4/30: Loss=0.017 | AUC=0.9937 | Best=0.9930
#   Epoch 5/30: Loss=0.013 | AUC=0.9928 | Best=0.9937
#   Epoch 6/30: Loss=0.008 | AUC=0.9952 | Best=0.9937
#   Epoch 7/30: Loss=0.010 | AUC=0.9916 | Best=0.9952
#   Epoch 8/30: Loss=0.007 | AUC=0.9947 | Best=0.9952
#   Epoch 9/30: Loss=0.001 | AUC=0.9959 | Best=0.9952
#   Epoch 10/30: Loss=0.000 | AUC=0.9962 | Best=0.9959
#   Epoch 11/30: Loss=0.000 | AUC=0.9960 | Best=0.9962
#   Epoch 12/30: Loss=0.002 | AUC=0.9959 | Best=0.9962
#   Epoch 13/30: Loss=0.003 | AUC=0.9949 | Best=0.9962
#   Epoch 14/30: Loss=0.010 | AUC=0.9943 | Best=0.9962
#   Epoch 15/30: Loss=0.006 | AUC=0.9921 | Best=0.9962
#   🛑 Early stopping triggered at epoch 15
# ✅ pneumoniamnist | AUC: 0.9648 | Bench: 0.962 | Gap: +0.0028
#
# ======================================================================
# 🔬 ResNet-50 2D: retinamnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\retinamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\retinamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\retinamnist.npz
# ✅ Train: 1,080 | Val: 120 | Test: 400
# ✅ Model: 23,518,277 params
#   Epoch 1/30: Loss=1.253 | AUC=0.7667 | Best=0.0000
#   Epoch 2/30: Loss=0.935 | AUC=0.7940 | Best=0.7667
#   Epoch 3/30: Loss=0.532 | AUC=0.7216 | Best=0.7940
#   Epoch 4/30: Loss=0.252 | AUC=0.7615 | Best=0.7940
#   Epoch 5/30: Loss=0.135 | AUC=0.6550 | Best=0.7940
#   Epoch 6/30: Loss=0.124 | AUC=0.7386 | Best=0.7940
#   Epoch 7/30: Loss=0.107 | AUC=0.7424 | Best=0.7940
#   🛑 Early stopping triggered at epoch 7
# ✅ retinamnist | AUC: 0.6975 | Bench: 0.716 | Gap: -0.0185
#
# ======================================================================
# 🔬 ResNet-50 2D: breastmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\breastmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\breastmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\breastmnist.npz
# ✅ Train: 546 | Val: 78 | Test: 156
# ✅ Model: 23,512,130 params
#   Epoch 1/30: Loss=0.514 | AUC=0.8133 | Best=0.0000
#   Epoch 2/30: Loss=0.168 | AUC=0.5673 | Best=0.8133
#   Epoch 3/30: Loss=0.032 | AUC=0.7393 | Best=0.8133
#   Epoch 4/30: Loss=0.029 | AUC=0.8338 | Best=0.8133
#   Epoch 5/30: Loss=0.036 | AUC=0.8496 | Best=0.8338
#   Epoch 6/30: Loss=0.008 | AUC=0.8889 | Best=0.8496
#   Epoch 7/30: Loss=0.006 | AUC=0.8713 | Best=0.8889
#   Epoch 8/30: Loss=0.032 | AUC=0.9114 | Best=0.8889
#   Epoch 9/30: Loss=0.016 | AUC=0.9165 | Best=0.9114
#   Epoch 10/30: Loss=0.022 | AUC=0.9231 | Best=0.9165
#   Epoch 11/30: Loss=0.016 | AUC=0.9424 | Best=0.9231
#   Epoch 12/30: Loss=0.018 | AUC=0.9424 | Best=0.9424
#   Epoch 13/30: Loss=0.012 | AUC=0.9541 | Best=0.9424
#   Epoch 14/30: Loss=0.017 | AUC=0.9457 | Best=0.9541
#   Epoch 15/30: Loss=0.006 | AUC=0.9457 | Best=0.9541
#   Epoch 16/30: Loss=0.002 | AUC=0.9348 | Best=0.9541
#   Epoch 17/30: Loss=0.032 | AUC=0.9398 | Best=0.9541
#   Epoch 18/30: Loss=0.003 | AUC=0.9357 | Best=0.9541
#   🛑 Early stopping triggered at epoch 18
# ✅ breastmnist | AUC: 0.8807 | Bench: 0.866 | Gap: +0.0147
#
# ======================================================================
# 🔬 ResNet-50 2D: bloodmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\bloodmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\bloodmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\bloodmnist.npz
# ✅ Train: 11,959 | Val: 1,712 | Test: 3,421
# ✅ Model: 23,524,424 params
#   Epoch 1/30: Loss=0.364 | AUC=0.9957 | Best=0.0000
#   Epoch 2/30: Loss=0.129 | AUC=0.9970 | Best=0.9957
#   Epoch 3/30: Loss=0.053 | AUC=0.9980 | Best=0.9970
#   Epoch 4/30: Loss=0.033 | AUC=0.9975 | Best=0.9980
#   Epoch 5/30: Loss=0.019 | AUC=0.9980 | Best=0.9980
#   Epoch 6/30: Loss=0.016 | AUC=0.9981 | Best=0.9980
#   Epoch 7/30: Loss=0.008 | AUC=0.9978 | Best=0.9981
#   Epoch 8/30: Loss=0.012 | AUC=0.9979 | Best=0.9981
#   Epoch 9/30: Loss=0.009 | AUC=0.9983 | Best=0.9981
#   Epoch 10/30: Loss=0.003 | AUC=0.9983 | Best=0.9983
#   Epoch 11/30: Loss=0.006 | AUC=0.9981 | Best=0.9983
#   Epoch 12/30: Loss=0.003 | AUC=0.9979 | Best=0.9983
#   Epoch 13/30: Loss=0.001 | AUC=0.9979 | Best=0.9983
#   Epoch 14/30: Loss=0.001 | AUC=0.9980 | Best=0.9983
#   🛑 Early stopping triggered at epoch 14
# ✅ bloodmnist | AUC: 0.9973 | Bench: 0.998 | Gap: -0.0007
#
# ======================================================================
# 🔬 ResNet-50 2D: tissuemnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\tissuemnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\tissuemnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\tissuemnist.npz
# ✅ Train: 165,466 | Val: 23,640 | Test: 47,280
# ✅ Model: 23,524,424 params
#   Epoch 1/30: Loss=1.043 | AUC=0.9168 | Best=0.0000
#   Epoch 2/30: Loss=0.887 | AUC=0.9221 | Best=0.9168
#   Epoch 3/30: Loss=0.765 | AUC=0.9257 | Best=0.9221
#   Epoch 4/30: Loss=0.589 | AUC=0.9190 | Best=0.9257
#   Epoch 5/30: Loss=0.357 | AUC=0.9093 | Best=0.9257
#   Epoch 6/30: Loss=0.185 | AUC=0.9050 | Best=0.9257
#   Epoch 7/30: Loss=0.119 | AUC=0.9036 | Best=0.9257
#   Epoch 8/30: Loss=0.091 | AUC=0.9008 | Best=0.9257
#   🛑 Early stopping triggered at epoch 8
# ✅ tissuemnist | AUC: 0.9257 | Bench: 0.932 | Gap: -0.0063
#
# ======================================================================
# 🔬 ResNet-50 2D: organamnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\organamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organamnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organamnist.npz
# ✅ Train: 34,561 | Val: 6,491 | Test: 17,778
# ✅ Model: 23,530,571 params
#   Epoch 1/30: Loss=0.174 | AUC=0.9995 | Best=0.0000
#   Epoch 2/30: Loss=0.035 | AUC=0.9995 | Best=0.9995
#   Epoch 3/30: Loss=0.023 | AUC=0.9999 | Best=0.9995
#   Epoch 4/30: Loss=0.014 | AUC=0.9999 | Best=0.9999
#   Epoch 5/30: Loss=0.012 | AUC=0.9999 | Best=0.9999
#   Epoch 6/30: Loss=0.008 | AUC=0.9999 | Best=0.9999
#   Epoch 7/30: Loss=0.007 | AUC=0.9997 | Best=0.9999
#   Epoch 8/30: Loss=0.015 | AUC=0.9999 | Best=0.9999
#   Epoch 9/30: Loss=0.003 | AUC=0.9999 | Best=0.9999
#   Epoch 10/30: Loss=0.004 | AUC=0.9998 | Best=0.9999
#   Epoch 11/30: Loss=0.007 | AUC=0.9999 | Best=0.9999
#   Epoch 12/30: Loss=0.002 | AUC=0.9999 | Best=0.9999
#   Epoch 13/30: Loss=0.000 | AUC=0.9999 | Best=0.9999
#   Epoch 14/30: Loss=0.000 | AUC=0.9999 | Best=0.9999
#   Epoch 15/30: Loss=0.003 | AUC=0.9998 | Best=0.9999
#   Epoch 16/30: Loss=0.003 | AUC=0.9999 | Best=0.9999
#   🛑 Early stopping triggered at epoch 16
# ✅ organamnist | AUC: 0.9984 | Bench: 0.998 | Gap: +0.0004
#
# ======================================================================
# 🔬 ResNet-50 2D: organcmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\organcmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organcmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organcmnist.npz
# ✅ Train: 12,975 | Val: 2,392 | Test: 8,216
# ✅ Model: 23,530,571 params
#   Epoch 1/30: Loss=0.320 | AUC=0.9992 | Best=0.0000
#   Epoch 2/30: Loss=0.091 | AUC=0.9997 | Best=0.9992
#   Epoch 3/30: Loss=0.046 | AUC=0.9997 | Best=0.9997
#   Epoch 4/30: Loss=0.024 | AUC=0.9996 | Best=0.9997
#   Epoch 5/30: Loss=0.015 | AUC=0.9997 | Best=0.9997
#   Epoch 6/30: Loss=0.007 | AUC=0.9997 | Best=0.9997
#   Epoch 7/30: Loss=0.013 | AUC=0.9997 | Best=0.9997
#   Epoch 8/30: Loss=0.012 | AUC=0.9996 | Best=0.9997
#   Epoch 9/30: Loss=0.002 | AUC=0.9999 | Best=0.9997
#   Epoch 10/30: Loss=0.000 | AUC=0.9999 | Best=0.9999
#   Epoch 11/30: Loss=0.001 | AUC=0.9999 | Best=0.9999
#   Epoch 12/30: Loss=0.001 | AUC=0.9996 | Best=0.9999
#   Epoch 13/30: Loss=0.005 | AUC=0.9996 | Best=0.9999
#   Epoch 14/30: Loss=0.007 | AUC=0.9996 | Best=0.9999
#   🛑 Early stopping triggered at epoch 14
# ✅ organcmnist | AUC: 0.9957 | Bench: 0.993 | Gap: +0.0027
#
# ======================================================================
# 🔬 ResNet-50 2D: organsmnist
# ======================================================================
# Using downloaded and verified file: C:\Users\User\.medmnist\organsmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organsmnist.npz
# Using downloaded and verified file: C:\Users\User\.medmnist\organsmnist.npz
# ✅ Train: 13,932 | Val: 2,452 | Test: 8,827
# ✅ Model: 23,530,571 params
#   Epoch 1/30: Loss=0.539 | AUC=0.9935 | Best=0.0000
#   Epoch 2/30: Loss=0.235 | AUC=0.9939 | Best=0.9935
#   Epoch 3/30: Loss=0.142 | AUC=0.9941 | Best=0.9939
#   Epoch 4/30: Loss=0.094 | AUC=0.9940 | Best=0.9941
#   Epoch 5/30: Loss=0.064 | AUC=0.9936 | Best=0.9941
#   Epoch 6/30: Loss=0.035 | AUC=0.9939 | Best=0.9941
#   Epoch 7/30: Loss=0.018 | AUC=0.9938 | Best=0.9941
#   Epoch 8/30: Loss=0.018 | AUC=0.9930 | Best=0.9941
#   🛑 Early stopping triggered at epoch 8
# ✅ organsmnist | AUC: 0.9801 | Bench: 0.975 | Gap: +0.0051
#
# ================================================================================
# 🎯 FINAL RESULTS (ACS for 3D)
# ================================================================================
# Dataset              AUC        Benchmark  Gap
# ------------------------------------------------------------
#
# 📊 3D RESULTS (ACS - All Slices)
# ------------------------------------------------------------
# adrenalmnist3d       0.8418     0.889         -0.0472 ✅
# fracturemnist3d      0.7242     0.871         -0.1468 🔴
# nodulemnist3d        0.8954     0.913         -0.0176 ✅
# organmnist3d         0.9741     0.995         -0.0209 ✅
# synapsemnist3d       0.9149     0.975         -0.0601 ✅
# vesselmnist3d        0.8913     0.899         -0.0077 ✅
#
# 📊 2D RESULTS
# ------------------------------------------------------------
# pathmnist            0.9922     0.989         +0.0032 ✅
# chestmnist           0.7669     0.773         -0.0061 ✅
# dermamnist           0.9243     0.920         +0.0043 ✅
# octmnist             0.9586     0.958         +0.0006 ✅
# pneumoniamnist       0.9648     0.962         +0.0028 ✅
# retinamnist          0.6975     0.716         -0.0185 ✅
# breastmnist          0.8807     0.866         +0.0147 ✅
# bloodmnist           0.9973     0.998         -0.0007 ✅
# tissuemnist          0.9257     0.932         -0.0063 ✅
# organamnist          0.9984     0.998         +0.0004 ✅
# organcmnist          0.9957     0.993         +0.0027 ✅
# organsmnist          0.9801     0.975         +0.0051 ✅
# ================================================================================
# 📈 Average AUC: 0.9069
# ================================================================================
