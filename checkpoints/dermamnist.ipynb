# %%
# !pip install medmnist
# !pip install torch torchvision
# !pip install tensorboardX
# !pip install tqdm
# !pip install git+https://github.com/M3DV/ACSConv.git  # For 3D datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.0 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/M3DV/ACSConv.git to /tmp/pip-req-build-o2au3_5i
#   Running command git clone --filter=blob:none --quiet https://github.com/M3DV/ACSConv.git /tmp/pip-req-build-o2au3_5i
#   Resolved https://github.com/M3DV/ACSConv.git to commit d1d60c83f4503c5a83aeecf7f816983351a7fa7f
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ACSConv: filename=ACSConv-0.1.1-py3-none-any.whl size=26976 sha256=9dbcd474810bd6dc7dc06f4e73160f10ddf8165b718541c279bd44f1631f312c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j_l_po7s/wheels/9b/f1/c9/cd0ddaa32d58a56e954d28b4684812a3c262213ddc4a85dc94
# Successfully built ACSConv
# ...

# %%
# !git clone https://github.com/MedMNIST/experiments.git
# Out:
# Cloning into 'experiments'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 89 (delta 15), reused 11 (delta 11), pack-reused 67 (from 1)
# Receiving objects: 100% (89/89), 36.99 KiB | 4.62 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# %cd experiments/MedMNIST2D
# Out:
# /content/experiments/MedMNIST2D

# %%
# Run training for dermamnist dataset with output saved separately
# !python train_and_eval_pytorch.py \
    --data_flag dermamnist \
    --output_root ./output/dermamnist_run1 \
    --num_epochs 10 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run4
# Out:
# ==> Preparing data...
# 100% 19.7M/19.7M [00:33<00:00, 596kB/s]
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.8611418570173871
# cur_best_epoch 0
#  10% 1/10 [01:47<16:09, 107.71s/it]cur_best_auc: 0.8795265554536398
# cur_best_epoch 1
#  20% 2/10 [03:45<15:11, 113.92s/it]cur_best_auc: 0.8977575042789832
# cur_best_epoch 2
#  50% 5/10 [09:39<09:45, 117.07s/it]cur_best_auc: 0.9133633639490881
# cur_best_epoch 5
# ...

# %%
# !python train_and_eval_pytorch.py \
    --data_flag dermamnist \
    --output_root ./output/dermamnist_run3 \
    --num_epochs 10 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run3
# Out:
# ==> Preparing data...
# 100% 19.7M/19.7M [00:32<00:00, 602kB/s]
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.8501423366706898
# cur_best_epoch 0
#  10% 1/10 [01:47<16:04, 107.20s/it]cur_best_auc: 0.8601623199063315
# cur_best_epoch 1
#  20% 2/10 [03:34<14:18, 107.32s/it]cur_best_auc: 0.8666758042895047
# cur_best_epoch 2
#  30% 3/10 [05:22<12:33, 107.68s/it]cur_best_auc: 0.8688809470354962
# cur_best_epoch 3
# ...

# %%
# !python train_and_eval_pytorch.py \
    --data_flag dermamnist \
    --output_root ./output/dermamnist_run2 \
    --num_epochs 10 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run2
# Out:
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.8442993376595906
# cur_best_epoch 0
#  10% 1/10 [01:48<16:19, 108.89s/it]cur_best_auc: 0.885028611121819
# cur_best_epoch 1
#  30% 3/10 [05:25<12:39, 108.52s/it]cur_best_auc: 0.8861350978947881
# cur_best_epoch 3
#  40% 4/10 [07:13<10:50, 108.37s/it]cur_best_auc: 0.9004235175088132
# cur_best_epoch 4
#  50% 5/10 [09:02<09:01, 108.33s/it]cur_best_auc: 0.9148830423296767
# ...

# %%
# !python train_and_eval_pytorch.py \
    --data_flag dermamnist \
    --output_root ./output/dermamnist_run1 \
    --num_epochs 10 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run1
# Out:
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.8625488343567869
# cur_best_epoch 0
#  10% 1/10 [01:49<16:29, 109.94s/it]cur_best_auc: 0.8761636075646962
# cur_best_epoch 1
#  30% 3/10 [05:25<12:38, 108.35s/it]cur_best_auc: 0.8866660301405183
# cur_best_epoch 3
#  50% 5/10 [09:01<08:59, 107.91s/it]cur_best_auc: 0.9081518837811579
# cur_best_epoch 5
#  60% 6/10 [10:48<07:11, 107.82s/it]cur_best_auc: 0.9100554307933081
# ...

# %%
# !python train_and_eval_pytorch.py \
    --data_flag dermamnist \
    --output_root ./output/dermamnist_run0 \
    --num_epochs 10 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run0
# Out:
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.8543946624938249
# cur_best_epoch 0
#  10% 1/10 [01:49<16:28, 109.82s/it]cur_best_auc: 0.8640825273437522
# cur_best_epoch 1
#  20% 2/10 [03:37<14:30, 108.84s/it]cur_best_auc: 0.8908022558578254
# cur_best_epoch 2
#  50% 5/10 [09:02<09:01, 108.25s/it]cur_best_auc: 0.9132728047989003
# cur_best_epoch 5
#  60% 6/10 [10:50<07:12, 108.16s/it]cur_best_auc: 0.9137265571634805
# ...
