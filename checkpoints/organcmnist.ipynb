# %%
# !pip install medmnist
# !pip install torch torchvision
# !pip install tensorboardX
# !pip install tqdm
# !pip install git+https://github.com/M3DV/ACSConv.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.6 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/M3DV/ACSConv.git to /tmp/pip-req-build-mplzsh8w
#   Running command git clone --filter=blob:none --quiet https://github.com/M3DV/ACSConv.git /tmp/pip-req-build-mplzsh8w
#   Resolved https://github.com/M3DV/ACSConv.git to commit d1d60c83f4503c5a83aeecf7f816983351a7fa7f
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ACSConv: filename=ACSConv-0.1.1-py3-none-any.whl size=26976 sha256=e11fa81a9596cc8075d45fd461d289304b3c1e75e9161fb310356646de059f4a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0dx8ec1_/wheels/9b/f1/c9/cd0ddaa32d58a56e954d28b4684812a3c262213ddc4a85dc94
# Successfully built ACSConv
# ...

# %%
# !git clone https://github.com/MedMNIST/experiments.git
# Out:
# Cloning into 'experiments'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 89 (delta 15), reused 11 (delta 11), pack-reused 67 (from 1)
# Receiving objects: 100% (89/89), 36.99 KiB | 5.28 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# %cd experiments/MedMNIST2D
# Out:
# /content/experiments/MedMNIST2D

# %%
# !python train_and_eval_pytorch.py \
    --data_flag organcmnist \
    --output_root ./output/organcmnist_run1 \
    --num_epochs 10 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run1
# Out:
# ==> Preparing data...
# 100% 15.5M/15.5M [00:26<00:00, 593kB/s]
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.9889551840423969
# cur_best_epoch 0
#  10% 1/10 [03:44<33:36, 224.02s/it]cur_best_auc: 0.9913665652328034
# cur_best_epoch 1
#  20% 2/10 [07:27<29:48, 223.58s/it]cur_best_auc: 0.998269186865268
# cur_best_epoch 2
#  30% 3/10 [11:10<26:04, 223.54s/it]cur_best_auc: 0.9995047504358382
# cur_best_epoch 3
# ...

# %%
# !python train_and_eval_pytorch.py \
    --data_flag organcmnist \
    --output_root ./output/organcmnist_run2 \
    --num_epochs 10 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run2
# Out:
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/10 [00:00<?, ?it/s]cur_best_auc: 0.9970009389818969
# cur_best_epoch 0
#  10% 1/10 [03:44<33:43, 224.85s/it]cur_best_auc: 0.9990033061403776
# cur_best_epoch 1
#  40% 4/10 [14:55<22:21, 223.65s/it]cur_best_auc: 0.9996302500784625
# cur_best_epoch 4
#  50% 5/10 [18:39<18:37, 223.55s/it]cur_best_auc: 0.9998372786209486
# cur_best_epoch 5
#  70% 7/10 [26:07<11:11, 223.76s/it]cur_best_auc: 0.999845828716646
# ...

# %%
# !python train_and_eval_pytorch.py \
    --data_flag organcmnist \
    --output_root ./output/organcmnist_run3 \
    --num_epochs 5 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run3
# Out:
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9879430051578414
# cur_best_epoch 0
#  20% 1/5 [03:55<15:41, 235.48s/it]cur_best_auc: 0.9966478267704786
# cur_best_epoch 1
#  40% 2/5 [07:48<11:42, 234.15s/it]cur_best_auc: 0.9986297013788827
# cur_best_epoch 2
#  80% 4/5 [15:34<03:53, 233.32s/it]cur_best_auc: 0.999398255129718
# cur_best_epoch 4
# 100% 5/5 [19:26<00:00, 233.33s/it]
# organcmnist
# ...

# %%
# !python train_and_eval_pytorch.py \
    --data_flag organcmnist \
    --output_root ./output/organcmnist_run4 \
    --num_epochs 5 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run4
# Out:
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9870074107908317
# cur_best_epoch 0
#  20% 1/5 [03:55<15:40, 235.13s/it]cur_best_auc: 0.996348362981763
# cur_best_epoch 1
#  40% 2/5 [07:49<11:43, 234.44s/it]cur_best_auc: 0.9987383913002771
# cur_best_epoch 2
# 100% 5/5 [19:28<00:00, 233.65s/it]
# organcmnist
# train  auc: 0.99455  acc: 0.91252
# val  auc: 0.99874  acc: 0.94691
# test  auc: 0.98075  acc: 0.83751

# %%
# !python train_and_eval_pytorch.py \
    --data_flag organcmnist \
    --output_root ./output/organcmnist_run5 \
    --num_epochs 5 \
    --batch_size 128 \
    --model_flag resnet50 \
    --resize \
    --as_rgb \
    --download \
    --run run5
# Out:
# ==> Preparing data...
# ==> Building and training model...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0% 0/5 [00:00<?, ?it/s]cur_best_auc: 0.9786958030342086
# cur_best_epoch 0
#  20% 1/5 [03:56<15:47, 236.82s/it]cur_best_auc: 0.9921987526482721
# cur_best_epoch 1
#  40% 2/5 [07:49<11:43, 234.37s/it]cur_best_auc: 0.9991637621795854
# cur_best_epoch 2
# 100% 5/5 [19:29<00:00, 233.87s/it]
# organcmnist
# train  auc: 0.99700  acc: 0.92069
# val  auc: 0.99916  acc: 0.94273
# test  auc: 0.98623  acc: 0.84640
